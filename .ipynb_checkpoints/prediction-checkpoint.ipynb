# %%
# !pip install lightgbm;
# !pip install optuna;
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lightgbm in /home/kvats/.local/lib/python3.11/site-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/lib/python3.11/site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.11/site-packages (from lightgbm) (1.13.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: optuna in /home/kvats/.local/lib/python3.11/site-packages (4.1.0)
# Requirement already satisfied: alembic>=1.5.0 in /opt/conda/lib/python3.11/site-packages (from optuna) (1.13.1)
# Requirement already satisfied: colorlog in /home/kvats/.local/lib/python3.11/site-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from optuna) (24.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /opt/conda/lib/python3.11/site-packages (from optuna) (2.0.29)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.11/site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (1.3.3)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy>=1.4.2->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/conda/lib/python3.11/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)

# %%
import json
import gzip
import math
import numpy as np
import random
import statistics
import scipy.stats
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import datetime
from tqdm import tqdm
import sys
import warnings
import re

# %%
warnings.filterwarnings("ignore")
sns.set_style("white")
sns.despine()
plt.rcParams['font.family'] = 'monospace'

# %%
event_df = pd.read_csv('train_logs.csv.zip')
event_df
# Out:
#                id  event_id  down_time  up_time  action_time       activity  \
# 0        001519c8         1       4526     4557           31  Nonproduction
# 1        001519c8         2       4558     4962          404  Nonproduction
# 2        001519c8         3     106571   106571            0  Nonproduction
# 3        001519c8         4     106686   106777           91          Input
# 4        001519c8         5     107196   107323          127          Input
# ...           ...       ...        ...      ...          ...            ...
# 8405893  fff05981      3615    2063944  2064440          496  Nonproduction
# 8405894  fff05981      3616    2064497  2064497            0  Nonproduction
# 8405895  fff05981      3617    2064657  2064765          108        Replace
# 8405896  fff05981      3618    2069186  2069259           73  Nonproduction
# 8405897  fff05981      3619    2070065  2070133           68          Input
#
#         down_event   up_event text_change  cursor_position  word_count
# 0        Leftclick  Leftclick    NoChange                0           0
# 1        Leftclick  Leftclick    NoChange                0           0
# 2            Shift      Shift    NoChange                0           0
# 3                q          q           q                1           1
# 4                q          q           q                2           1
# ...            ...        ...         ...              ...         ...
# 8405893  Leftclick  Leftclick    NoChange             1031         240
# 8405894      Shift      Shift    NoChange             1031         240
# 8405895          q          q      q => q             1031         240
# 8405896  Leftclick  Leftclick    NoChange             1028         240
# 8405897          .          .           .             1029         240
#
# [8405898 rows x 11 columns]

# %%
score_df = pd.read_csv('train_scores.csv')
score_df = score_df.set_index('id')
score_df
# Out:
#           score
# id
# 001519c8    3.5
# 0022f953    3.5
# 0042269b    6.0
# 0059420b    2.0
# 0075873a    4.0
# ...         ...
# ffb8c745    3.5
# ffbef7e5    4.0
# ffccd6fd    1.5
# ffec5b38    5.0
# fff05981    4.0
#
# [2471 rows x 1 columns]

# %% [markdown]
# # Exploratory Data Analysis
#
# I chose this data due to my personal interest in the use of typing patterns as indicators of certain behaviors, and this was a great way to understand the structure / nature of most typing data sets & train models on them.
#
# ## First, let's look at the distribution of scores
#
# We are trying to predict essay scores, so let's examine scores of essays

# %%
x1 = score_df["score"]
# Plot
# kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2}, bins=[0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6])

fig, ax = plt.subplots(figsize=(12,4), dpi= 100)
sns.despine()
ax = sns.histplot(x1, kde=True, line_kws={'linewidth':2},alpha=0.6, bins=[0.75,1.25,1.75,2.25,2.75,3.25,3.75,4.25,4.75,5.25,5.75,6.25])

# %% [markdown]
# ## Let's create some more basic features:
# - `num_events` the number of events
# - `num_deletions` number of deletions
# - `num_words` final word count of essay

# %%
## Functions for basic features:
def num_events(essay_id, df_dict):
    ft_df = df_dict[essay_id]
    return len(ft_df)

def num_deletions(essay_id, df_dict):
    counts =  df_dict[essay_id]['activity'].value_counts()
    if 'Remove/Cut' in counts.index:
        return counts['Remove/Cut']
    else:
        return 0

def num_words(essay_id, df_dict):
    count = df_dict[essay_id]['word_count'].iloc[-1]
    return count

# %%
## Create a dict of essay id to pandas dataframe - easy to get a specific dataframe's essay for feature extraction
essay_events = dict(tuple(event_df.groupby('id')))

# %%
x1 = [num_events(index, essay_events) for index, row in score_df.iterrows()]
x2 = [num_deletions(index, essay_events) for index, row in score_df.iterrows()]
x3 = [num_words(index, essay_events) for index, row in score_df.iterrows()]

# plot
fig, axes = plt.subplots(1, 3, figsize=(10, 3), sharey=True, dpi=100)
sns.histplot(x1 , color="dodgerblue", kde=True, ax=axes[0]).set_xlabel('Number of Events')
sns.histplot(x2 , color="deeppink", kde=True, ax=axes[1]).set_xlabel('Number of Deletions');
sns.histplot(x3 , color="orangered", kde=True, ax=axes[2]).set_xlabel('Number of Words');

# %% [markdown]
# ## These distributions are clearly log-scaled, so let's make features that take the log of both of them
#
# New Features:
#
# - `log_num_events`
# - `log_num_deletions`
# - `log_num_words`

# %%
def log_num_events(essay_id, df_dict):
    return math.log2(num_events(essay_id, df_dict))

def log_num_deletions(essay_id, df_dict):
    return math.log2(num_deletions(essay_id, df_dict) + 1) # offset for log

def log_num_words(essay_id, df_dict):
    return math.log2(num_words(essay_id, df_dict))

# %%
x1 = [log_num_events(index, essay_events) for index, row in score_df.iterrows()]
x2 = [log_num_deletions(index, essay_events) for index, row in score_df.iterrows()]
x3 = [log_num_words(index, essay_events) for index, row in score_df.iterrows()]

# plot
fig, axes = plt.subplots(1, 3, figsize=(10, 3), sharey=True, dpi=100)
sns.histplot(x1 , color="dodgerblue", kde=True, ax=axes[0]).set_xlabel('Log Number of Events')
sns.histplot(x2 , color="deeppink", kde=True, ax=axes[1]).set_xlabel('Log Number of Deletions');
sns.histplot(x3 , color="orangered", kde=True, ax=axes[2]).set_xlabel('Log Number of Words');

# %% [markdown]
# # Prediction
#
# ## Naive Approach (Linear Regression)
#
# The dataset has keystrokes from users, but the keys are anonymized as 'q' so the goal is to use the timestamps / ordering of events to train some model to predict the score of each essay. There are about 2500 users' essays in the dataset and nearly 8.5 million events, so I'll definitely have to drastically reduce dimensionality when I do regular classification. For now, though, we can see if we can fit a regression between # of events and the score for each essay.

# %%
from sklearn import linear_model

# %%
def MSE(predictions, actual):
    return sum((predictions[i] - actual[i])**2 for i in range(len(predictions))) / len(predictions)

# %%
## Train / Valid / Test Split:
seeds = 2004, 1983, 12

splits = [np.split(
    score_df.sample(frac=1, random_state = seed), [int(0.5 * len(score_df))]) for seed in seeds]

train_score_dfs = [split[0] for split in splits]
test_score_dfs = [split[1] for split in splits]

# %%
## All features separate: log and not log

X_trains_num_events = [[[num_events(essay_id, essay_events)] 
                         for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]
X_trains_log_num_events = [[[log_num_events(essay_id, essay_events)] 
                         for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]
X_trains_num_deletions = [[[num_deletions(essay_id, essay_events)] 
                         for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]
X_trains_log_num_deletions = [[[log_num_deletions(essay_id, essay_events)] 
                         for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]
X_trains_num_words = [[[num_words(essay_id, essay_events)] 
                         for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]
X_trains_log_num_words = [[[log_num_words(essay_id, essay_events)] 
                         for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]

y_trains = [[row['score'] for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]


X_tests_num_events = [[[num_events(essay_id, essay_events)] 
                         for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]
X_tests_log_num_events = [[[log_num_events(essay_id, essay_events)] 
                         for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]
X_tests_num_deletions = [[[num_deletions(essay_id, essay_events)] 
                         for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]
X_tests_log_num_deletions = [[[log_num_deletions(essay_id, essay_events)] 
                         for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]
X_tests_num_words = [[[num_words(essay_id, essay_events)] 
                         for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]
X_tests_log_num_words = [[[log_num_words(essay_id, essay_events)] 
                         for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]


y_tests = [[row['score'] for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]

# %%
regs_num_events = [linear_model.LinearRegression().fit(X_train, y_train) for (X_train, y_train) in zip(X_trains_num_events, y_trains)]

regs_log_num_events = [linear_model.LinearRegression().fit(X_train, y_train) for (X_train, y_train) in zip(X_trains_log_num_events, y_trains)]

regs_num_deletions = [linear_model.LinearRegression().fit(X_train, y_train) for (X_train, y_train) in zip(X_trains_num_deletions, y_trains)]

regs_log_num_deletions = [linear_model.LinearRegression().fit(X_train, y_train) for (X_train, y_train) in zip(X_trains_log_num_deletions, y_trains)]

regs_num_words = [linear_model.LinearRegression().fit(X_train, y_train) for (X_train, y_train) in zip(X_trains_num_words, y_trains)]

regs_log_num_words = [linear_model.LinearRegression().fit(X_train, y_train) for (X_train, y_train) in zip(X_trains_log_num_words, y_trains)]

# %%
y_preds_num_events = [reg.predict(X_test) for (reg, X_test) in zip(regs_num_events, X_tests_num_events)]
MSE_num_events = [MSE(y_pred, y_test) for y_pred, y_test in zip(y_preds_num_events, y_tests)]
print(f"MSES for num events: {MSE_num_events}") 

y_preds_log_num_events = [reg.predict(X_test) for (reg, X_test) in zip(regs_log_num_events, X_tests_log_num_events)]
MSE_log_num_events = [MSE(y_pred, y_test) for y_pred, y_test in zip(y_preds_log_num_events, y_tests)]
print(f"MSES for log num events: {MSE_log_num_events}") 

y_preds_num_deletions = [reg.predict(X_test) for (reg, X_test) in zip(regs_num_deletions, X_tests_num_deletions)]
MSE_num_deletions = [MSE(y_pred, y_test) for y_pred, y_test in zip(y_preds_num_deletions, y_tests)]
print(f"MSES for num deletions: {MSE_num_deletions}") 

y_preds_log_num_deletions = [reg.predict(X_test) for (reg, X_test) in zip(regs_log_num_deletions, X_tests_log_num_deletions)]
MSE_log_num_deletions = [MSE(y_pred, y_test) for y_pred, y_test in zip(y_preds_log_num_deletions, y_tests)]
print(f"MSES for log num deletions: {MSE_log_num_deletions}") 

y_preds_num_words = [reg.predict(X_test) for (reg, X_test) in zip(regs_num_words, X_tests_num_words)]
MSE_num_words = [MSE(y_pred, y_test) for y_pred, y_test in zip(y_preds_num_words, y_tests)]
print(f"MSES for num words: {MSE_num_words}") 

y_preds_log_num_words = [reg.predict(X_test) for (reg, X_test) in zip(regs_log_num_words, X_tests_log_num_words)]
MSE_log_num_words = [MSE(y_pred, y_test) for y_pred, y_test in zip(y_preds_log_num_words, y_tests)]
print(f"MSES for log num words: {MSE_log_num_words}")
# Out:
# MSES for num events: [0.6803616180630022, 0.7232688922009521, 0.7238584583279332]
# MSES for log num events: [0.6203263985569867, 0.640463715584686, 0.6334569957435457]
# MSES for num deletions: [0.9623295991847461, 1.001622481505261, 1.0019244005218984]
# MSES for log num deletions: [0.8905918720329442, 0.9228960614109114, 0.9019916447223087]
# MSES for num words: [0.6030279358014377, 0.635038230199783, 0.6420673056192123]
# MSES for log num words: [0.5301670106313389, 0.5577847982455166, 0.5560860065876809]

# %%
## All features combined
X_trains_combined = [[[log_num_events(essay_id, essay_events), log_num_words(essay_id, essay_events)] 
                         for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]

X_tests_combined = [[[log_num_events(essay_id, essay_events), log_num_words(essay_id, essay_events)] 
                         for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]

regs_combined = [linear_model.LinearRegression().fit(X_train, y_train) for (X_train, y_train) in zip(X_trains_combined, y_trains)]

# %%
y_preds_combined = [reg.predict(X_test) for (reg, X_test) in zip(regs_combined, X_tests_combined)]
MSE_combined = [MSE(y_pred, y_test) for y_pred, y_test in zip(y_preds_combined, y_tests)]
print(f"MSES for log features combined: {MSE_combined}")
# Out:
# MSES for log features combined: [0.5228547055186219, 0.5423025499955366, 0.5400855623894222]

# %%
X_train_final = [[log_num_events(essay_id, essay_events), log_num_deletions(essay_id, essay_events)] for essay_id, row in score_df.iterrows()]
y_train_final = [row['score'] for essay_id, row in score_df.iterrows()]
final_reg = linear_model.LinearRegression().fit(X_train_final, y_train_final)

# %%
# Make predictions on the test data
final_df = pd.read_csv('test_logs.csv')
final_df = final_df.set_index('id')
final_events = dict(tuple(final_df.groupby('id')))

print(final_df)

X_test_final = [[log_num_events(essay_id, final_events), log_num_deletions(essay_id, final_events)] for essay_id, row in final_df.iterrows()]

test_predictions = final_reg.predict(X_test_final)
print(X_test_final)
print(test_predictions)

# Create a submission DataFrame
submission = pd.DataFrame({'id': final_df.index, 'score': test_predictions})

# Remove duplicates from the submission DataFrame
submission.drop_duplicates(subset=['id'], keep='last', inplace=True)

# Save the submission file
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# ### Submitted to Kaggle, MSE: 0.576 RMSE Private / 0.594 RMSE Public
#
# ## Enough is Enough with the linear regressions! Let's use LGBM to actually quantify which features are impactful, then make some more

# %%
# First thing is to get organized - need to have a way to add any features to a dataframe
# Desired feature is an array of (string, function) representing the name of feature and the function to calculate that feature for an id
def calculate_features(df_dict, desired_features, df):
    feature_df = df.copy()
    for (feature_name, feature_funct) in tqdm(desired_features):
        feature_list = [feature_funct(essay_id, df_dict) for essay_id, row in df.iterrows()]
        feature_df[feature_name] = feature_list
    return feature_df

# %%
from sklearn.model_selection import KFold

# %%
## Now, let's organize our splits with K-Fold Cross Validation
cross_validator = KFold(n_splits = 5, shuffle=True, random_state = 4444)

## Cross validation function to run any model on our folds & give all of the MSES
def cross_validate(model, df, cross_validator):
    X = df.drop('score', axis=1)
    y = df['score']

    mses = {}
    for fold, (train_index, valid_index) in enumerate(cross_validator.split(X, y)):
        X_train = X.iloc[train_index]
        X_valid = X.iloc[valid_index]
        y_train = y.iloc[train_index]
        y_valid = y.iloc[valid_index]

        model.fit(X_train, y_train,
                 eval_set=[(X_valid, y_valid)],
                 eval_metric="mse"  
                 )

        y_pred = model.predict(X_valid)

        mses[fold] = MSE(y_pred, y_valid)
        #print(mses[fold])

    return mses

# %% [markdown]
# ## Time to engineer some new features!
#
# These are feature recommendations from the paper *{ENTER}ing the Time Series {SPACE}: Uncovering the Writing Process through Keystroke Analyses* (Allen et al.).
#
# Using big words is probably indicative of high vocabulary. Creating a feature that weighs big words a certain way can lead to a stronger model.
# - `avg_word_length`, `max_word_length`, `std_word_length`, `skew_word_length`
# Experienced writers can probably type fast. People pause while writing, but each pause while writing is probably no more than a second, so let's calculate typing speed & keep all pauses out of influencing this average.
# - `avg_typing_speed`, `std_typing_speed`, `skew_typing_speed`, `kurtosis_typing_speed`
# A good writer probably also takes certain amount of pauses between writing, so let's calculate the following:
# - `pauses_0.5_second`, `pauses_1_second`, `pauses_1.5_second`, `pauses_2_second`, `pauses_2.5_second`, `pauses_3_second`

# %%
def avg_word_length(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return np.mean([len(word) for word in word_list(essay_df)])

def max_word_length(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return max([len(word) for word in word_list(essay_df)])

def std_word_length(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return np.std([len(word) for word in word_list(essay_df)])

def skew_word_length(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return scipy.stats.skew([len(word) for word in word_list(essay_df)])

def kurtosis_word_length(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return scipy.stats.kurtosis([len(word) for word in word_list(essay_df)])

## To do this efficiently, we should separate each essay in into words just once and make a column, calculate these stats, then delete the column

def words_longer_5(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return sum([len(word) > 5 for word in word_list(essay_df)])

def words_longer_8(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return sum([len(word) > 8 for word in word_list(essay_df)])


def word_list(essay_df):
    inputs_df = essay_df[essay_df['activity'] == 'Input']
    rough_essay = "".join(list(inputs_df['text_change']))
    return re.findall(r'q+', rough_essay)

# %%
def avg_typing_speed(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return np.mean(typing_gaps(essay_df))
    
def std_typing_speed(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return np.std(typing_gaps(essay_df))

def skew_typing_speed(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return scipy.stats.skew(typing_gaps(essay_df))

def kurtosis_typing_speed(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return scipy.stats.kurtosis(typing_gaps(essay_df))

def typing_gaps(essay_df):
    down_times = list(essay_df['down_time'])
    typing_gaps = [down_times[i] - down_times[i-1] for i in range(1,len(down_times))]
    typing_gaps_cleaned = [typing_gap for typing_gap in typing_gaps if typing_gap < 1000]
    return typing_gaps_cleaned

# %%
def pause_0_5_second(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return pauses(essay_df, 500)

def pause_1_second(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return pauses(essay_df, 1000)

def pause_1_5_second(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return pauses(essay_df, 1500)

def pause_2_second(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return pauses(essay_df, 2000)

def pause_2_5_second(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return pauses(essay_df, 2500)

def pause_3_second(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return pauses(essay_df, 3000)

def pauses(essay_df, threshold):
    down_times = list(essay_df['down_time'])
    typing_gaps = [down_times[i] - down_times[i-1] for i in range(1,len(down_times))]
    return sum(typing_gap > threshold for typing_gap in typing_gaps)

# %%
desired_features = [('num_deletions', num_deletions), ('num_events', num_events), 
                    ('num_words', num_words), ('avg_word_length', avg_word_length ), ('max_word_length', max_word_length), 
                    ('std_word_length', std_word_length), ('skew_word_length', skew_word_length), 
                    ('kurtosis_word_length', kurtosis_word_length), ('words_longer_5', words_longer_5), ('words_longer_8', words_longer_8),
                    ('avg_typing_speed', avg_typing_speed), ('skew_typing_speed', skew_typing_speed),
                    ('std_typing_speed', std_typing_speed), ('kurtosis_typing_speed', kurtosis_typing_speed),
                    ('pause_0_5_second', pause_0_5_second), ('pause_1_second', pause_1_second), ('pause_1_5_second', pause_1_5_second), 
                    ('pause_2_second', pause_2_second), ('pause_2_5_second', pause_2_5_second), ('pause_3_second', pause_3_second) 
                   ]
features_df = calculate_features(essay_events, desired_features, score_df)
# Out:
# 100%|██████████| 20/20 [00:54<00:00,  2.73s/it]

# %%
features_df
# Out:
#           score  log_num_deletions  log_num_events  log_num_words  \
# id
# 001519c8    3.5           8.707359       11.320236       7.994353
# 0022f953    3.5           8.027906       11.260920       8.321928
# 0042269b    6.0           8.781360       12.014020       8.658211
# 0059420b    2.0           7.247928       10.603626       7.686501
# 0075873a    4.0           9.016808       11.305492       7.977280
# ...         ...                ...             ...            ...
# ffb8c745    3.5           9.908393       12.210367       8.092757
# ffbef7e5    4.0           5.930737       11.346514       8.774787
# ffccd6fd    1.5           6.475733       11.580730       7.651052
# ffec5b38    5.0           8.113742       11.662668       8.689998
# fff05981    4.0           8.280771       11.821375       7.906891
#
#           avg_word_length  max_word_length  std_word_length  skew_word_length  \
# id
# 001519c8         4.947853               14         2.786973          0.827438
# 0022f953         4.090659               22         2.452857          2.413930
# 0042269b         5.267273               17         2.960869          0.952503
# 0059420b         4.417021               16         2.714133          1.556064
# 0075873a         4.492711               20         2.763639          1.415424
# ...                   ...              ...              ...               ...
# ffb8c745         4.722591               14         2.742151          0.976979
# ffbef7e5         4.054113               13         2.182004          0.829613
# ffccd6fd         4.465438               14         2.532727          1.024942
# ffec5b38         5.055675               18         3.122946          1.322251
# fff05981         4.937500               22         3.289163          1.207315
#
#           kurtosis_word_length  words_longer_5  ...  avg_typing_speed  \
# id                                              ...
# 001519c8             -0.049868             115  ...        191.752467
# 0022f953             10.364904              66  ...        204.746626
# 0042269b              0.505729             211  ...        128.186949
# 0059420b              3.035786              65  ...        276.027544
# 0075873a              3.009695              86  ...        191.495819
# ...                        ...             ...  ...               ...
# ffb8c745              0.433473             183  ...        150.037405
# ffbef7e5              0.670496             103  ...        280.717284
# ffccd6fd              0.906297              65  ...        210.667254
# ffec5b38              1.874763             163  ...        204.355026
# fff05981              1.788361             147  ...        223.820474
#
#           skew_typing_speed  std_typing_speed  kurtosis_typing_speed  \
# id
# 001519c8           2.318082        162.628704               5.783103
# 0022f953           2.343222        168.221909               5.768109
# 0042269b           3.822477        122.898182              17.112811
# 0059420b           1.000082        214.720553               0.471059
# 0075873a           1.953751        146.650059               5.140510
# ...                     ...               ...                    ...
# ffb8c745           3.151022        131.307351              12.292701
# ffbef7e5           1.516782        152.033856               3.608851
# ffccd6fd           1.268971        203.953535               1.451127
# ffec5b38           2.232826        153.263791               6.129929
# fff05981           2.071887        187.547088               4.245710
#
#           pause_0_5_second  pause_1_second  pause_1_5_second  pause_2_second  \
# id
# 001519c8               385             225               164             135
# 0022f953               330             155               102              85
# 0042269b               291             166               116              84
# 0059420b               464             248               139              93
# 0075873a               246             138               104              92
# ...                    ...             ...               ...             ...
# ffb8c745               276             113                64              46
# ffbef7e5               354             173               121              92
# ffccd6fd               518             221               131              91
# ffec5b38               315             137                97              70
# fff05981               596             287               179             122
#
#           pause_2_5_second  pause_3_second
# id
# 001519c8               118             104
# 0022f953                73              63
# 0042269b                69              56
# 0059420b                73              59
# 0075873a                78              73
# ...                    ...             ...
# ffb8c745                41              31
# ffbef7e5                77              69
# ffccd6fd                72              60
# ffec5b38                53              49
# fff05981               100              84
#
# [2471 rows x 21 columns]

# %%
fig, axes = plt.subplots(5, 5, figsize=(20, 25), sharey=False, dpi=100)

axes = axes.flatten()

palette = sns.color_palette("husl", len(features_df.columns))

for idx, column in tqdm(enumerate(features_df.columns)):
    sns.histplot(features_df[column], color=palette[idx], kde=True, ax=axes[idx])
    axes[idx].set_xlabel(f'{column}')

for j in range(len(ft_df.columns), len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 21it [00:15,  1.34it/s]

# %% [markdown]
# ## A lot of them are skewed, so let's just take the log of every feature. LGBM will lower influence of redundant onces

# %%
ft_df = features_df.copy()
    
for col in features_df.select_dtypes(include=[np.number]).columns:
    shifted_col = features_df[col] - features_df[col].min() + 1e-6
    ft_df[f'log_{col}'] = np.log(shifted_col)

ft_df = ft_df.drop('log_score', axis = 1)

# %%
correlation_matrix = ft_df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## LGBM

# %%
import lightgbm as lgbm
import optuna

# %%
def objective(trial):
    # Define hyperparameter search space
    param = {
        "n_estimators": trial.suggest_int("n_estimators", 20, 920, step=100),
    "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.1, log=True), 
    "num_leaves": trial.suggest_int("num_leaves", 31, 128),  # Increase num_leaves
    "max_depth": trial.suggest_int("max_depth", 5, 15),
    "min_child_samples": trial.suggest_int("min_child_samples", 20, 100),
    "subsample": trial.suggest_float("subsample", 0.6, 1.0),
    "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
    "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),
    "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 10.0, log=True),
    }


    model = lgbm.LGBMRegressor(
        **param,
        random_state = 2004,
        verbose = -1
    )

    
    
    mse = np.mean(list(cross_validate(model, ft_df, cross_validator).values()))
    return mse

# Optimize hyperparameters
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=100)

# Print best hyperparameters
print("Best trial:")
print(f"  Value: {study.best_trial.value}")
print(f"  Params: {study.best_trial.params}")
# Out:
# [I 2024-11-30 07:46:01,384] A new study created in memory with name: no-name-6c836713-e7c6-4817-902f-78ca1193a583
# [I 2024-11-30 07:46:02,355] Trial 0 finished with value: 0.4392972266195506 and parameters: {'n_estimators': 220, 'learning_rate': 0.052156939032009166, 'num_leaves': 76, 'max_depth': 15, 'min_child_samples': 100, 'subsample': 0.9926992300434596, 'colsample_bytree': 0.8629787161740194, 'reg_alpha': 4.96855303880753e-06, 'reg_lambda': 5.8698159367828944e-05}. Best is trial 0 with value: 0.4392972266195506.
# [I 2024-11-30 07:46:04,001] Trial 1 finished with value: 0.458767550854864 and parameters: {'n_estimators': 320, 'learning_rate': 0.06139920741742472, 'num_leaves': 69, 'max_depth': 14, 'min_child_samples': 64, 'subsample': 0.6576946092244839, 'colsample_bytree': 0.6914755805686139, 'reg_alpha': 2.05192194967371e-06, 'reg_lambda': 0.7363289837190566}. Best is trial 0 with value: 0.4392972266195506.
# [I 2024-11-30 07:46:05,209] Trial 2 finished with value: 0.4512085611473228 and parameters: {'n_estimators': 220, 'learning_rate': 0.007444857327933737, 'num_leaves': 76, 'max_depth': 6, 'min_child_samples': 54, 'subsample': 0.9824191504122193, 'colsample_bytree': 0.8356112642020195, 'reg_alpha': 6.200134244490514e-07, 'reg_lambda': 7.048242645707054e-06}. Best is trial 0 with value: 0.4392972266195506.
# [I 2024-11-30 07:46:08,518] Trial 3 finished with value: 0.44199269835897625 and parameters: {'n_estimators': 820, 'learning_rate': 0.0023583921313638572, 'num_leaves': 89, 'max_depth': 7, 'min_child_samples': 78, 'subsample': 0.920738119840795, 'colsample_bytree': 0.6109216256968759, 'reg_alpha': 0.26894833538825996, 'reg_lambda': 0.0438233155652506}. Best is trial 0 with value: 0.4392972266195506.
# [I 2024-11-30 07:46:16,621] Trial 4 finished with value: 0.434861091211986 and parameters: {'n_estimators': 720, 'learning_rate': 0.0050350945425546535, 'num_leaves': 99, 'max_depth': 13, 'min_child_samples': 22, 'subsample': 0.7096443767656117, 'colsample_bytree': 0.6345803511660916, 'reg_alpha': 2.0895594491529517e-06, 'reg_lambda': 1.5224927721622588}. Best is trial 4 with value: 0.434861091211986.
# [I 2024-11-30 07:46:18,649] Trial 5 finished with value: 0.4322558275725549 and parameters: {'n_estimators': 520, 'learning_rate': 0.021194108213550705, 'num_leaves': 42, 'max_depth': 10, 'min_child_samples': 85, 'subsample': 0.9386953899153175, 'colsample_bytree': 0.6835174166199494, 'reg_alpha': 0.2993191357825087, 'reg_lambda': 7.714429541347231}. Best is trial 5 with value: 0.4322558275725549.
# [I 2024-11-30 07:46:21,369] Trial 6 finished with value: 0.44077171219221445 and parameters: {'n_estimators': 220, 'learning_rate': 0.008740278516341123, 'num_leaves': 123, 'max_depth': 12, 'min_child_samples': 23, 'subsample': 0.8852248585143285, 'colsample_bytree': 0.8971171316752846, 'reg_alpha': 9.41103542667013e-07, 'reg_lambda': 1.5464383040218219e-07}. Best is trial 5 with value: 0.4322558275725549.
# [I 2024-11-30 07:46:21,946] Trial 7 finished with value: 0.43580599953780236 and parameters: {'n_estimators': 120, 'learning_rate': 0.08134123961613747, 'num_leaves': 113, 'max_depth': 9, 'min_child_samples': 64, 'subsample': 0.9871978107608186, 'colsample_bytree': 0.5683008437200128, 'reg_alpha': 0.8982260165056335, 'reg_lambda': 9.6087546747141e-07}. Best is trial 5 with value: 0.4322558275725549.
# [I 2024-11-30 07:46:24,029] Trial 8 finished with value: 0.4275221581748602 and parameters: {'n_estimators': 320, 'learning_rate': 0.012218158020564751, 'num_leaves': 108, 'max_depth': 13, 'min_child_samples': 47, 'subsample': 0.7158592476822228, 'colsample_bytree': 0.7952101637777402, 'reg_alpha': 6.792441412033612e-05, 'reg_lambda': 0.7870597467633786}. Best is trial 8 with value: 0.4275221581748602.
# [I 2024-11-30 07:46:25,769] Trial 9 finished with value: 0.5022149839820089 and parameters: {'n_estimators': 320, 'learning_rate': 0.003598896900896555, 'num_leaves': 71, 'max_depth': 13, 'min_child_samples': 49, 'subsample': 0.8070543865561792, 'colsample_bytree': 0.9881351258142923, 'reg_alpha': 2.4001709568784526, 'reg_lambda': 0.012462047108854263}. Best is trial 8 with value: 0.4275221581748602.
# [I 2024-11-30 07:46:29,573] Trial 10 finished with value: 0.5755887425805196 and parameters: {'n_estimators': 520, 'learning_rate': 0.0014135988609635093, 'num_leaves': 43, 'max_depth': 11, 'min_child_samples': 41, 'subsample': 0.6034133433519462, 'colsample_bytree': 0.7635336361825945, 'reg_alpha': 0.0011323295863056326, 'reg_lambda': 0.0023127343104161514}. Best is trial 8 with value: 0.4275221581748602.
# [I 2024-11-30 07:46:31,403] Trial 11 finished with value: 0.4344911556673824 and parameters: {'n_estimators': 520, 'learning_rate': 0.022945469695939913, 'num_leaves': 31, 'max_depth': 9, 'min_child_samples': 86, 'subsample': 0.7645210596561983, 'colsample_bytree': 0.5066002953383453, 'reg_alpha': 0.0025356208304940157, 'reg_lambda': 6.494828329684859}. Best is trial 8 with value: 0.4275221581748602.
# [I 2024-11-30 07:46:34,960] Trial 12 finished with value: 0.4461591493023408 and parameters: {'n_estimators': 620, 'learning_rate': 0.01994024959898125, 'num_leaves': 53, 'max_depth': 10, 'min_child_samples': 38, 'subsample': 0.7905453272256854, 'colsample_bytree': 0.7314401343416538, 'reg_alpha': 1.3562885488788642e-08, 'reg_lambda': 0.2926050602958298}. Best is trial 8 with value: 0.4275221581748602.
# [I 2024-11-30 07:46:35,176] Trial 13 finished with value: 0.7675331107244924 and parameters: {'n_estimators': 20, 'learning_rate': 0.016987910275079017, 'num_leaves': 103, 'max_depth': 8, 'min_child_samples': 77, 'subsample': 0.8658163736762036, 'colsample_bytree': 0.8026595350651312, 'reg_alpha': 0.028754663978557662, 'reg_lambda': 9.005637006376576}. Best is trial 8 with value: 0.4275221581748602.
# [I 2024-11-30 07:46:38,613] Trial 14 finished with value: 0.467158345798396 and parameters: {'n_estimators': 920, 'learning_rate': 0.03561190647798515, 'num_leaves': 58, 'max_depth': 11, 'min_child_samples': 98, 'subsample': 0.7344171669762858, 'colsample_bytree': 0.6938464566266156, 'reg_alpha': 8.005076019333953e-05, 'reg_lambda': 0.0006239947848096536}. Best is trial 8 with value: 0.4275221581748602.
# [I 2024-11-30 07:46:40,027] Trial 15 finished with value: 0.4257343013883025 and parameters: {'n_estimators': 420, 'learning_rate': 0.01647147525867266, 'num_leaves': 122, 'max_depth': 5, 'min_child_samples': 73, 'subsample': 0.8331021723281394, 'colsample_bytree': 0.8976482924086395, 'reg_alpha': 8.457257047436758e-05, 'reg_lambda': 0.0642950825538176}. Best is trial 15 with value: 0.4257343013883025.
# [I 2024-11-30 07:46:41,595] Trial 16 finished with value: 0.4219369482220367 and parameters: {'n_estimators': 420, 'learning_rate': 0.012119635255168954, 'num_leaves': 127, 'max_depth': 5, 'min_child_samples': 69, 'subsample': 0.8278750489399967, 'colsample_bytree': 0.949256067428791, 'reg_alpha': 0.00013979061962522308, 'reg_lambda': 0.03628667976354456}. Best is trial 16 with value: 0.4219369482220367.
# [I 2024-11-30 07:46:42,899] Trial 17 finished with value: 0.4403398043438208 and parameters: {'n_estimators': 420, 'learning_rate': 0.040070569167001496, 'num_leaves': 127, 'max_depth': 5, 'min_child_samples': 72, 'subsample': 0.8317216444163629, 'colsample_bytree': 0.9930369811765171, 'reg_alpha': 4.732714368032848e-05, 'reg_lambda': 0.02536469363959626}. Best is trial 16 with value: 0.4219369482220367.
# [I 2024-11-30 07:46:45,029] Trial 18 finished with value: 0.42371400846279117 and parameters: {'n_estimators': 620, 'learning_rate': 0.011102108379419615, 'num_leaves': 118, 'max_depth': 5, 'min_child_samples': 68, 'subsample': 0.8473210541845839, 'colsample_bytree': 0.9222845323158295, 'reg_alpha': 0.016521010761600247, 'reg_lambda': 6.888355907762187e-05}. Best is trial 16 with value: 0.4219369482220367.
# [I 2024-11-30 07:46:48,436] Trial 19 finished with value: 0.42152023793142224 and parameters: {'n_estimators': 720, 'learning_rate': 0.005928392102288688, 'num_leaves': 91, 'max_depth': 6, 'min_child_samples': 57, 'subsample': 0.8669097233090153, 'colsample_bytree': 0.9461107182149529, 'reg_alpha': 0.005350279966323518, 'reg_lambda': 3.9818273984429244e-05}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:46:53,716] Trial 20 finished with value: 0.4265983469988811 and parameters: {'n_estimators': 720, 'learning_rate': 0.004858168244172437, 'num_leaves': 90, 'max_depth': 7, 'min_child_samples': 33, 'subsample': 0.8975183918798549, 'colsample_bytree': 0.9460101976020538, 'reg_alpha': 0.025753134919970364, 'reg_lambda': 7.741962620218197e-06}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:46:56,292] Trial 21 finished with value: 0.42402700788066755 and parameters: {'n_estimators': 620, 'learning_rate': 0.010501868785313246, 'num_leaves': 115, 'max_depth': 6, 'min_child_samples': 58, 'subsample': 0.8492563802871822, 'colsample_bytree': 0.9290418160568419, 'reg_alpha': 0.021935537017287714, 'reg_lambda': 0.00010299156521681545}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:46:58,946] Trial 22 finished with value: 0.4216802191518047 and parameters: {'n_estimators': 720, 'learning_rate': 0.006468079804392098, 'num_leaves': 91, 'max_depth': 5, 'min_child_samples': 66, 'subsample': 0.7915236210602103, 'colsample_bytree': 0.9421406700408974, 'reg_alpha': 0.0034225300544284596, 'reg_lambda': 0.0018337873628895746}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:03,737] Trial 23 finished with value: 0.4272767843719992 and parameters: {'n_estimators': 920, 'learning_rate': 0.0027529029193868234, 'num_leaves': 88, 'max_depth': 6, 'min_child_samples': 56, 'subsample': 0.7798749176157126, 'colsample_bytree': 0.9687753422761441, 'reg_alpha': 0.001206202238247147, 'reg_lambda': 0.002451767332662917}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:06,888] Trial 24 finished with value: 0.4233754838254309 and parameters: {'n_estimators': 820, 'learning_rate': 0.006246031754431404, 'num_leaves': 101, 'max_depth': 7, 'min_child_samples': 85, 'subsample': 0.7507355580318985, 'colsample_bytree': 0.8723775335842636, 'reg_alpha': 0.0030714739628749503, 'reg_lambda': 0.0036914958663753035}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:10,192] Trial 25 finished with value: 0.5089062640431159 and parameters: {'n_estimators': 720, 'learning_rate': 0.0014883808836432346, 'num_leaves': 94, 'max_depth': 5, 'min_child_samples': 63, 'subsample': 0.8216145709252203, 'colsample_bytree': 0.9491851358028445, 'reg_alpha': 0.0003494126348118806, 'reg_lambda': 0.00030564253118005655}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:13,361] Trial 26 finished with value: 0.4432354199448296 and parameters: {'n_estimators': 820, 'learning_rate': 0.0031445406476493538, 'num_leaves': 84, 'max_depth': 8, 'min_child_samples': 55, 'subsample': 0.8866205883397157, 'colsample_bytree': 0.8283401264099146, 'reg_alpha': 9.430925183322191, 'reg_lambda': 2.2066073603817575e-08}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:16,218] Trial 27 finished with value: 0.42689744724624745 and parameters: {'n_estimators': 620, 'learning_rate': 0.004603512558052757, 'num_leaves': 63, 'max_depth': 6, 'min_child_samples': 68, 'subsample': 0.9404865126012124, 'colsample_bytree': 0.8980576989750713, 'reg_alpha': 1.17005935532459e-05, 'reg_lambda': 8.738590422777621e-06}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:19,080] Trial 28 finished with value: 0.5587450055931467 and parameters: {'n_estimators': 420, 'learning_rate': 0.0019193480933746968, 'num_leaves': 108, 'max_depth': 8, 'min_child_samples': 47, 'subsample': 0.6726289490425368, 'colsample_bytree': 0.8605143994012182, 'reg_alpha': 0.0003088036683034659, 'reg_lambda': 0.10998443622974907}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:21,705] Trial 29 finished with value: 0.4233879476480372 and parameters: {'n_estimators': 720, 'learning_rate': 0.007207345744307297, 'num_leaves': 82, 'max_depth': 7, 'min_child_samples': 95, 'subsample': 0.804649940734481, 'colsample_bytree': 0.9679115030315276, 'reg_alpha': 0.006854967653395494, 'reg_lambda': 0.00032272148170601735}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:23,927] Trial 30 finished with value: 0.4422059227364218 and parameters: {'n_estimators': 820, 'learning_rate': 0.02814599490669073, 'num_leaves': 97, 'max_depth': 5, 'min_child_samples': 80, 'subsample': 0.8669439611057974, 'colsample_bytree': 0.8597578691420199, 'reg_alpha': 1.5866901095087036e-05, 'reg_lambda': 0.009155985499499076}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:27,208] Trial 31 finished with value: 0.4243478539255957 and parameters: {'n_estimators': 820, 'learning_rate': 0.00638947095565796, 'num_leaves': 102, 'max_depth': 6, 'min_child_samples': 71, 'subsample': 0.7516338614173007, 'colsample_bytree': 0.909812812287854, 'reg_alpha': 0.07360563762571022, 'reg_lambda': 0.0013461914966349136}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:30,322] Trial 32 finished with value: 0.43429641783780576 and parameters: {'n_estimators': 920, 'learning_rate': 0.01291208799525549, 'num_leaves': 78, 'max_depth': 7, 'min_child_samples': 91, 'subsample': 0.7606276948054617, 'colsample_bytree': 0.8762101361586105, 'reg_alpha': 0.0004074465343180564, 'reg_lambda': 0.004180206567158969}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:33,115] Trial 33 finished with value: 0.42352353499348877 and parameters: {'n_estimators': 720, 'learning_rate': 0.005865562768253569, 'num_leaves': 109, 'max_depth': 6, 'min_child_samples': 83, 'subsample': 0.7881294657302174, 'colsample_bytree': 0.9496205081301266, 'reg_alpha': 0.003078044720281244, 'reg_lambda': 2.0442528389780204e-05}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:37,790] Trial 34 finished with value: 0.4334595657136154 and parameters: {'n_estimators': 820, 'learning_rate': 0.009180051405946582, 'num_leaves': 71, 'max_depth': 15, 'min_child_samples': 61, 'subsample': 0.6849816694010273, 'colsample_bytree': 0.9955374213763385, 'reg_alpha': 0.005450033013060299, 'reg_lambda': 0.000153032683119692}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:40,583] Trial 35 finished with value: 0.4317790475712848 and parameters: {'n_estimators': 620, 'learning_rate': 0.003931594879931633, 'num_leaves': 93, 'max_depth': 7, 'min_child_samples': 90, 'subsample': 0.7235919140828457, 'colsample_bytree': 0.8351700514891511, 'reg_alpha': 0.14276146332516887, 'reg_lambda': 1.4785645369966164e-06}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:42,495] Trial 36 finished with value: 0.4243396661361628 and parameters: {'n_estimators': 520, 'learning_rate': 0.007558996949458356, 'num_leaves': 86, 'max_depth': 5, 'min_child_samples': 76, 'subsample': 0.9103077274112203, 'colsample_bytree': 0.8645041407358465, 'reg_alpha': 0.0008613177006994584, 'reg_lambda': 0.007736784208307286}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:47,283] Trial 37 finished with value: 0.5513226907513078 and parameters: {'n_estimators': 820, 'learning_rate': 0.0010206056298760328, 'num_leaves': 102, 'max_depth': 6, 'min_child_samples': 51, 'subsample': 0.7429367282337653, 'colsample_bytree': 0.9342565436685841, 'reg_alpha': 1.0910866077936528e-07, 'reg_lambda': 0.15288683732437916}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:48,497] Trial 38 finished with value: 0.49619486627262555 and parameters: {'n_estimators': 220, 'learning_rate': 0.005252527749348175, 'num_leaves': 128, 'max_depth': 9, 'min_child_samples': 67, 'subsample': 0.6991154644501659, 'colsample_bytree': 0.9704622035407644, 'reg_alpha': 0.010656735136241876, 'reg_lambda': 3.6151561656603306e-05}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:52,213] Trial 39 finished with value: 0.4338131337769887 and parameters: {'n_estimators': 920, 'learning_rate': 0.013071201304745605, 'num_leaves': 76, 'max_depth': 7, 'min_child_samples': 60, 'subsample': 0.9523559036583622, 'colsample_bytree': 0.881834856127085, 'reg_alpha': 0.062462777897970855, 'reg_lambda': 0.0007728511035926426}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:53,656] Trial 40 finished with value: 0.43279380420775276 and parameters: {'n_estimators': 320, 'learning_rate': 0.007320852040902106, 'num_leaves': 97, 'max_depth': 8, 'min_child_samples': 80, 'subsample': 0.8141476359680886, 'colsample_bytree': 0.8070686338253419, 'reg_alpha': 4.5495463502940916e-06, 'reg_lambda': 0.026759687427994106}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:56,287] Trial 41 finished with value: 0.42369647305503333 and parameters: {'n_estimators': 720, 'learning_rate': 0.007410990076785402, 'num_leaves': 81, 'max_depth': 7, 'min_child_samples': 95, 'subsample': 0.7733927493136559, 'colsample_bytree': 0.9702430488724816, 'reg_alpha': 0.005954510587608049, 'reg_lambda': 0.00026447124472322135}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:47:58,665] Trial 42 finished with value: 0.42677095558562694 and parameters: {'n_estimators': 720, 'learning_rate': 0.009470862792705186, 'num_leaves': 80, 'max_depth': 6, 'min_child_samples': 99, 'subsample': 0.8060861983520153, 'colsample_bytree': 0.9164567221310552, 'reg_alpha': 0.00016372018368265102, 'reg_lambda': 0.0005824513104981521}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:01,290] Trial 43 finished with value: 0.4273131853506572 and parameters: {'n_estimators': 720, 'learning_rate': 0.0040896498259998205, 'num_leaves': 66, 'max_depth': 5, 'min_child_samples': 91, 'subsample': 0.8555089517656305, 'colsample_bytree': 0.9667385108136536, 'reg_alpha': 0.0026925291892909904, 'reg_lambda': 1.2621238316586906e-06}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:03,806] Trial 44 finished with value: 0.42388363391120987 and parameters: {'n_estimators': 620, 'learning_rate': 0.005976603680243381, 'num_leaves': 91, 'max_depth': 7, 'min_child_samples': 85, 'subsample': 0.79722493339619, 'colsample_bytree': 0.9308639347396555, 'reg_alpha': 0.0008867958779493443, 'reg_lambda': 0.001741672583947843}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:05,596] Trial 45 finished with value: 0.4265809914969757 and parameters: {'n_estimators': 520, 'learning_rate': 0.016106491564502105, 'num_leaves': 84, 'max_depth': 6, 'min_child_samples': 94, 'subsample': 0.8734567766594604, 'colsample_bytree': 0.9626023585280469, 'reg_alpha': 0.6891310249072866, 'reg_lambda': 1.843663885924933e-05}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:07,790] Trial 46 finished with value: 0.4240488766579341 and parameters: {'n_estimators': 420, 'learning_rate': 0.008399272745897173, 'num_leaves': 112, 'max_depth': 9, 'min_child_samples': 65, 'subsample': 0.8326368059238693, 'colsample_bytree': 0.8891406648652742, 'reg_alpha': 0.010270277264525885, 'reg_lambda': 0.5543187378457031}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:11,319] Trial 47 finished with value: 0.42781262659177266 and parameters: {'n_estimators': 820, 'learning_rate': 0.0030948548404288673, 'num_leaves': 104, 'max_depth': 5, 'min_child_samples': 52, 'subsample': 0.6190243911616492, 'colsample_bytree': 0.7658718136600842, 'reg_alpha': 2.478081155192898e-05, 'reg_lambda': 0.004674311248793197}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:13,524] Trial 48 finished with value: 0.4969954312860402 and parameters: {'n_estimators': 520, 'learning_rate': 0.0022536140587718217, 'num_leaves': 119, 'max_depth': 8, 'min_child_samples': 88, 'subsample': 0.770832632756578, 'colsample_bytree': 0.9993705841929399, 'reg_alpha': 0.0020302735713293393, 'reg_lambda': 0.04196316143526657}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:17,651] Trial 49 finished with value: 0.4436134759664636 and parameters: {'n_estimators': 720, 'learning_rate': 0.013878346989212932, 'num_leaves': 74, 'max_depth': 11, 'min_child_samples': 43, 'subsample': 0.8175402611130115, 'colsample_bytree': 0.6588743749752288, 'reg_alpha': 0.07758515854833307, 'reg_lambda': 0.012800799289871434}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:18,286] Trial 50 finished with value: 0.5623639446768591 and parameters: {'n_estimators': 120, 'learning_rate': 0.006775532262748342, 'num_leaves': 98, 'max_depth': 5, 'min_child_samples': 74, 'subsample': 0.7336817982352232, 'colsample_bytree': 0.9101476525308752, 'reg_alpha': 0.00015076948916698955, 'reg_lambda': 3.8607212702596025e-06}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:21,097] Trial 51 finished with value: 0.4237076918074635 and parameters: {'n_estimators': 720, 'learning_rate': 0.005753489141042062, 'num_leaves': 108, 'max_depth': 6, 'min_child_samples': 83, 'subsample': 0.7916124979156047, 'colsample_bytree': 0.9426274362866406, 'reg_alpha': 0.003627071144759765, 'reg_lambda': 3.182427306072352e-05}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:24,051] Trial 52 finished with value: 0.4253228335384967 and parameters: {'n_estimators': 720, 'learning_rate': 0.004741514212606202, 'num_leaves': 110, 'max_depth': 6, 'min_child_samples': 83, 'subsample': 0.78516029750596, 'colsample_bytree': 0.9518691716497426, 'reg_alpha': 0.007624574438964106, 'reg_lambda': 0.00017177252836072973}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:26,196] Trial 53 finished with value: 0.48816670745527996 and parameters: {'n_estimators': 620, 'learning_rate': 0.09900903405192231, 'num_leaves': 124, 'max_depth': 7, 'min_child_samples': 79, 'subsample': 0.82984146646138, 'colsample_bytree': 0.9787240065369528, 'reg_alpha': 0.0006106250998649947, 'reg_lambda': 2.462100006030167e-07}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:28,805] Trial 54 finished with value: 0.4278264416751433 and parameters: {'n_estimators': 920, 'learning_rate': 0.010892189887111936, 'num_leaves': 116, 'max_depth': 6, 'min_child_samples': 96, 'subsample': 0.7569820233000941, 'colsample_bytree': 0.5710805966256719, 'reg_alpha': 0.002445999751676464, 'reg_lambda': 1.7485734683572513e-05}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:32,189] Trial 55 finished with value: 0.4263123488910927 and parameters: {'n_estimators': 820, 'learning_rate': 0.0035531207255239694, 'num_leaves': 94, 'max_depth': 5, 'min_child_samples': 69, 'subsample': 0.7993293817731949, 'colsample_bytree': 0.9543464746146176, 'reg_alpha': 0.03870923561697599, 'reg_lambda': 5.373999603962951e-05}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:34,593] Trial 56 finished with value: 0.4236046122588868 and parameters: {'n_estimators': 620, 'learning_rate': 0.00823045858442843, 'num_leaves': 105, 'max_depth': 7, 'min_child_samples': 87, 'subsample': 0.8446122689812414, 'colsample_bytree': 0.9266442015913072, 'reg_alpha': 0.0015677324138221613, 'reg_lambda': 0.0006376385708231762}. Best is trial 19 with value: 0.42152023793142224.
# [I 2024-11-30 07:48:37,968] Trial 57 finished with value: 0.4207282591452269 and parameters: {'n_estimators': 720, 'learning_rate': 0.005716226647986487, 'num_leaves': 83, 'max_depth': 6, 'min_child_samples': 58, 'subsample': 0.8793088609111839, 'colsample_bytree': 0.9825684219797995, 'reg_alpha': 0.19034174004445678, 'reg_lambda': 2.462364573380084e-06}. Best is trial 57 with value: 0.4207282591452269.
# [I 2024-11-30 07:48:39,838] Trial 58 finished with value: 0.4472067726477721 and parameters: {'n_estimators': 420, 'learning_rate': 0.004566420996302296, 'num_leaves': 82, 'max_depth': 5, 'min_child_samples': 56, 'subsample': 0.9013790745797561, 'colsample_bytree': 0.9785725283634666, 'reg_alpha': 2.68808864242034, 'reg_lambda': 4.6999773649910013e-07}. Best is trial 57 with value: 0.4207282591452269.
# [I 2024-11-30 07:48:43,613] Trial 59 finished with value: 0.42852253424920334 and parameters: {'n_estimators': 820, 'learning_rate': 0.009814167318595017, 'num_leaves': 86, 'max_depth': 8, 'min_child_samples': 60, 'subsample': 0.8773826869654464, 'colsample_bytree': 0.9053210039185797, 'reg_alpha': 0.12919495155996483, 'reg_lambda': 2.768452194375173}. Best is trial 57 with value: 0.4207282591452269.
# [I 2024-11-30 07:48:46,098] Trial 60 finished with value: 0.43791079435973546 and parameters: {'n_estimators': 320, 'learning_rate': 0.019937565024771366, 'num_leaves': 89, 'max_depth': 9, 'min_child_samples': 28, 'subsample': 0.9246690848243269, 'colsample_bytree': 0.727606576887946, 'reg_alpha': 0.47658494622947606, 'reg_lambda': 2.9673250804177313e-08}. Best is trial 57 with value: 0.4207282591452269.
# [I 2024-11-30 07:48:49,326] Trial 61 finished with value: 0.4206584771862999 and parameters: {'n_estimators': 720, 'learning_rate': 0.0056393770052036605, 'num_leaves': 95, 'max_depth': 6, 'min_child_samples': 63, 'subsample': 0.8878504034496447, 'colsample_bytree': 0.9461963774018123, 'reg_alpha': 0.01798687869762638, 'reg_lambda': 2.4825400047062355e-06}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:48:52,600] Trial 62 finished with value: 0.4213487237715654 and parameters: {'n_estimators': 720, 'learning_rate': 0.005351946456766932, 'num_leaves': 100, 'max_depth': 6, 'min_child_samples': 64, 'subsample': 0.8587944299999065, 'colsample_bytree': 0.9874164349383595, 'reg_alpha': 0.017008542474188357, 'reg_lambda': 4.736823777383912e-06}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:48:55,175] Trial 63 finished with value: 0.42246588033901195 and parameters: {'n_estimators': 620, 'learning_rate': 0.005386452824401848, 'num_leaves': 95, 'max_depth': 5, 'min_child_samples': 63, 'subsample': 0.8600260841820504, 'colsample_bytree': 0.9850131512288205, 'reg_alpha': 0.018609120883682533, 'reg_lambda': 3.5397892734630317e-06}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:48:57,773] Trial 64 finished with value: 0.4244421799144068 and parameters: {'n_estimators': 620, 'learning_rate': 0.0050697450507464804, 'num_leaves': 95, 'max_depth': 5, 'min_child_samples': 64, 'subsample': 0.88740242419296, 'colsample_bytree': 0.9965944513976367, 'reg_alpha': 0.22547428377546874, 'reg_lambda': 2.968310271736697e-06}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:01,336] Trial 65 finished with value: 0.42487235779643384 and parameters: {'n_estimators': 720, 'learning_rate': 0.00403836549199868, 'num_leaves': 90, 'max_depth': 6, 'min_child_samples': 62, 'subsample': 0.861769428902971, 'colsample_bytree': 0.9834093657317148, 'reg_alpha': 0.015465687321468745, 'reg_lambda': 3.8941201081788555e-06}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:03,680] Trial 66 finished with value: 0.4732235615804877 and parameters: {'n_estimators': 520, 'learning_rate': 0.0026412985615005486, 'num_leaves': 98, 'max_depth': 5, 'min_child_samples': 66, 'subsample': 0.9624085506739459, 'colsample_bytree': 0.9347545958486869, 'reg_alpha': 0.0351170992636595, 'reg_lambda': 7.207275756193673e-07}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:06,356] Trial 67 finished with value: 0.43931069460136785 and parameters: {'n_estimators': 620, 'learning_rate': 0.0033055355665757686, 'num_leaves': 91, 'max_depth': 5, 'min_child_samples': 70, 'subsample': 0.9205903047319031, 'colsample_bytree': 0.984041766828171, 'reg_alpha': 0.0169038791538099, 'reg_lambda': 1.6993976176204593e-07}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:09,728] Trial 68 finished with value: 0.42219332443946095 and parameters: {'n_estimators': 720, 'learning_rate': 0.0053754232724545605, 'num_leaves': 87, 'max_depth': 6, 'min_child_samples': 58, 'subsample': 0.8441732136912959, 'colsample_bytree': 0.9535502511145391, 'reg_alpha': 2.19256982508682, 'reg_lambda': 8.082605074152605e-06}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:13,282] Trial 69 finished with value: 0.42531599709057016 and parameters: {'n_estimators': 720, 'learning_rate': 0.0042018150097438076, 'num_leaves': 87, 'max_depth': 6, 'min_child_samples': 58, 'subsample': 0.8953965230091705, 'colsample_bytree': 0.8475117932412759, 'reg_alpha': 1.0737394939474925, 'reg_lambda': 8.611862569432702e-06}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:17,894] Trial 70 finished with value: 0.43256009644201726 and parameters: {'n_estimators': 820, 'learning_rate': 0.0114452300767068, 'num_leaves': 49, 'max_depth': 12, 'min_child_samples': 52, 'subsample': 0.8463701829174222, 'colsample_bytree': 0.9194844187118904, 'reg_alpha': 4.282854464316872, 'reg_lambda': 1.9192432080639715e-06}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:21,371] Trial 71 finished with value: 0.42274606780348456 and parameters: {'n_estimators': 720, 'learning_rate': 0.00525303268621189, 'num_leaves': 93, 'max_depth': 6, 'min_child_samples': 58, 'subsample': 0.87455470582817, 'colsample_bytree': 0.9493428100571982, 'reg_alpha': 1.4886415264908561, 'reg_lambda': 6.134232984689741e-06}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:24,099] Trial 72 finished with value: 0.4212785140388816 and parameters: {'n_estimators': 620, 'learning_rate': 0.006281301971547617, 'num_leaves': 76, 'max_depth': 5, 'min_child_samples': 63, 'subsample': 0.8396117878227185, 'colsample_bytree': 0.9589361552968114, 'reg_alpha': 0.24838612306338048, 'reg_lambda': 4.127245035594229e-07}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:27,476] Trial 73 finished with value: 0.4214403943429324 and parameters: {'n_estimators': 720, 'learning_rate': 0.006810743038708959, 'num_leaves': 74, 'max_depth': 6, 'min_child_samples': 54, 'subsample': 0.8443456697081783, 'colsample_bytree': 0.9579512294445973, 'reg_alpha': 0.3417399189535998, 'reg_lambda': 4.6230273047803073e-07}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:30,216] Trial 74 finished with value: 0.4228850471137132 and parameters: {'n_estimators': 620, 'learning_rate': 0.006754597849866794, 'num_leaves': 76, 'max_depth': 5, 'min_child_samples': 44, 'subsample': 0.8213580934357099, 'colsample_bytree': 0.9397631042215487, 'reg_alpha': 0.2940933664155618, 'reg_lambda': 7.030665202262596e-08}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:33,696] Trial 75 finished with value: 0.42475125532074254 and parameters: {'n_estimators': 820, 'learning_rate': 0.008309231072497274, 'num_leaves': 77, 'max_depth': 6, 'min_child_samples': 53, 'subsample': 0.8386507213747275, 'colsample_bytree': 0.8936908625325903, 'reg_alpha': 0.14905045960586813, 'reg_lambda': 5.57564720069963e-07}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:36,676] Trial 76 finished with value: 0.42237534314618524 and parameters: {'n_estimators': 720, 'learning_rate': 0.006173080990969925, 'num_leaves': 67, 'max_depth': 5, 'min_child_samples': 49, 'subsample': 0.9084325563403379, 'colsample_bytree': 0.9598537582613039, 'reg_alpha': 0.056949478928698984, 'reg_lambda': 3.5343500532582415e-07}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:39,828] Trial 77 finished with value: 0.42504417418644247 and parameters: {'n_estimators': 620, 'learning_rate': 0.007735483405171952, 'num_leaves': 60, 'max_depth': 14, 'min_child_samples': 72, 'subsample': 0.8848030301733757, 'colsample_bytree': 0.9239449758915479, 'reg_alpha': 0.11248876726860874, 'reg_lambda': 5.535264041479705e-08}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:41,941] Trial 78 finished with value: 0.42334267037676304 and parameters: {'n_estimators': 520, 'learning_rate': 0.009194737210591707, 'num_leaves': 70, 'max_depth': 6, 'min_child_samples': 75, 'subsample': 0.8587021877914812, 'colsample_bytree': 0.9768653333057695, 'reg_alpha': 0.36719996820725526, 'reg_lambda': 9.998298366096066e-07}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:45,039] Trial 79 finished with value: 0.43320478889308534 and parameters: {'n_estimators': 720, 'learning_rate': 0.01472257550306789, 'num_leaves': 84, 'max_depth': 7, 'min_child_samples': 55, 'subsample': 0.8719847756320663, 'colsample_bytree': 0.999974922248543, 'reg_alpha': 0.0375026842416977, 'reg_lambda': 1.0143509482979602e-07}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:48,750] Trial 80 finished with value: 0.42417524571291204 and parameters: {'n_estimators': 820, 'learning_rate': 0.004425451381620804, 'num_leaves': 73, 'max_depth': 6, 'min_child_samples': 67, 'subsample': 0.8142473601044162, 'colsample_bytree': 0.9652872981098278, 'reg_alpha': 0.5119010327683646, 'reg_lambda': 1.613792150600087e-06}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:51,915] Trial 81 finished with value: 0.43311458063318825 and parameters: {'n_estimators': 720, 'learning_rate': 0.0037054587542240496, 'num_leaves': 100, 'max_depth': 6, 'min_child_samples': 60, 'subsample': 0.8485776879214015, 'colsample_bytree': 0.9550823016167918, 'reg_alpha': 4.267149776706539, 'reg_lambda': 1.2826448423173655e-05}. Best is trial 61 with value: 0.4206584771862999.
# [I 2024-11-30 07:49:54,738] Trial 82 finished with value: 0.42041608267728714 and parameters: {'n_estimators': 720, 'learning_rate': 0.006515396758418711, 'num_leaves': 78, 'max_depth': 5, 'min_child_samples': 57, 'subsample': 0.8269361493925405, 'colsample_bytree': 0.9435182671453515, 'reg_alpha': 0.20602188350301334, 'reg_lambda': 1.861914365095981e-06}. Best is trial 82 with value: 0.42041608267728714.
# [I 2024-11-30 07:49:57,761] Trial 83 finished with value: 0.42293151622321734 and parameters: {'n_estimators': 720, 'learning_rate': 0.006363061459613017, 'num_leaves': 79, 'max_depth': 5, 'min_child_samples': 49, 'subsample': 0.8273061023072922, 'colsample_bytree': 0.9402175027974096, 'reg_alpha': 0.9285597362785206, 'reg_lambda': 2.519811412254155e-06}. Best is trial 82 with value: 0.42041608267728714.
# [I 2024-11-30 07:49:59,341] Trial 84 finished with value: 0.4218043852657149 and parameters: {'n_estimators': 420, 'learning_rate': 0.012087792831122662, 'num_leaves': 74, 'max_depth': 5, 'min_child_samples': 65, 'subsample': 0.8873413165951783, 'colsample_bytree': 0.9070343331528266, 'reg_alpha': 0.17558992333618387, 'reg_lambda': 3.2505693324119964e-07}. Best is trial 82 with value: 0.42041608267728714.
# [I 2024-11-30 07:50:01,986] Trial 85 finished with value: 0.42026734889378287 and parameters: {'n_estimators': 720, 'learning_rate': 0.006929010339829607, 'num_leaves': 74, 'max_depth': 5, 'min_child_samples': 63, 'subsample': 0.88349001110643, 'colsample_bytree': 0.9126589206083837, 'reg_alpha': 0.26123018376380863, 'reg_lambda': 1.0785415047975286e-08}. Best is trial 85 with value: 0.42026734889378287.
# [I 2024-11-30 07:50:04,785] Trial 86 finished with value: 0.4212864932943566 and parameters: {'n_estimators': 720, 'learning_rate': 0.006863687451221509, 'num_leaves': 66, 'max_depth': 5, 'min_child_samples': 54, 'subsample': 0.9225632029879942, 'colsample_bytree': 0.9205812770234348, 'reg_alpha': 0.0991674767663115, 'reg_lambda': 2.0018233415568898e-08}. Best is trial 85 with value: 0.42026734889378287.
# [I 2024-11-30 07:50:07,538] Trial 87 finished with value: 0.42148568605091297 and parameters: {'n_estimators': 720, 'learning_rate': 0.0069021420673233, 'num_leaves': 63, 'max_depth': 5, 'min_child_samples': 56, 'subsample': 0.9297108914729777, 'colsample_bytree': 0.8872277446412724, 'reg_alpha': 0.06470955089880852, 'reg_lambda': 1.3714241683291334e-08}. Best is trial 85 with value: 0.42026734889378287.
# [I 2024-11-30 07:50:09,810] Trial 88 finished with value: 0.42389049929377176 and parameters: {'n_estimators': 620, 'learning_rate': 0.01020060098710595, 'num_leaves': 62, 'max_depth': 5, 'min_child_samples': 54, 'subsample': 0.926552481130365, 'colsample_bytree': 0.8823507221648748, 'reg_alpha': 0.26963084938090764, 'reg_lambda': 1.1930168035654297e-08}. Best is trial 85 with value: 0.42026734889378287.
# [I 2024-11-30 07:50:12,675] Trial 89 finished with value: 0.42066046478239 and parameters: {'n_estimators': 820, 'learning_rate': 0.006992919989021933, 'num_leaves': 67, 'max_depth': 5, 'min_child_samples': 62, 'subsample': 0.9804575112945164, 'colsample_bytree': 0.8212078896791806, 'reg_alpha': 0.08086629165931276, 'reg_lambda': 1.3700158116117577e-08}. Best is trial 85 with value: 0.42026734889378287.
# [I 2024-11-30 07:50:15,408] Trial 90 finished with value: 0.42154574762149305 and parameters: {'n_estimators': 820, 'learning_rate': 0.00790955518030017, 'num_leaves': 68, 'max_depth': 5, 'min_child_samples': 62, 'subsample': 0.9792707634649012, 'colsample_bytree': 0.7534418935596755, 'reg_alpha': 0.09369843708560113, 'reg_lambda': 1.8865498130880762e-08}. Best is trial 85 with value: 0.42026734889378287.
# [I 2024-11-30 07:50:18,174] Trial 91 finished with value: 0.4238039058858777 and parameters: {'n_estimators': 720, 'learning_rate': 0.007186713585166556, 'num_leaves': 72, 'max_depth': 5, 'min_child_samples': 47, 'subsample': 0.9510101751722473, 'colsample_bytree': 0.7884755487364284, 'reg_alpha': 0.05273324090969272, 'reg_lambda': 1.0409953603607315e-08}. Best is trial 85 with value: 0.42026734889378287.
# [I 2024-11-30 07:50:21,318] Trial 92 finished with value: 0.4203702348194197 and parameters: {'n_estimators': 820, 'learning_rate': 0.0058074400312471625, 'num_leaves': 54, 'max_depth': 5, 'min_child_samples': 60, 'subsample': 0.9913984870724192, 'colsample_bytree': 0.9159613421710524, 'reg_alpha': 0.5533497047254315, 'reg_lambda': 3.797506256086928e-08}. Best is trial 85 with value: 0.42026734889378287.
# [I 2024-11-30 07:50:25,276] Trial 93 finished with value: 0.4222884778041692 and parameters: {'n_estimators': 920, 'learning_rate': 0.005680588532143505, 'num_leaves': 54, 'max_depth': 6, 'min_child_samples': 60, 'subsample': 0.9823008902915693, 'colsample_bytree': 0.9230226975276371, 'reg_alpha': 0.10365274353061886, 'reg_lambda': 3.960222993294808e-08}. Best is trial 85 with value: 0.42026734889378287.
# [I 2024-11-30 07:50:28,532] Trial 94 finished with value: 0.4206954316449812 and parameters: {'n_estimators': 820, 'learning_rate': 0.004768043037960378, 'num_leaves': 56, 'max_depth': 5, 'min_child_samples': 59, 'subsample': 0.9938174551593651, 'colsample_bytree': 0.8537140473337976, 'reg_alpha': 0.6054268376776697, 'reg_lambda': 1.2167030702322673e-07}. Best is trial 85 with value: 0.42026734889378287.
# [I 2024-11-30 07:50:31,658] Trial 95 finished with value: 0.4223989425616538 and parameters: {'n_estimators': 820, 'learning_rate': 0.004668955358651189, 'num_leaves': 54, 'max_depth': 5, 'min_child_samples': 64, 'subsample': 0.9778813303756839, 'colsample_bytree': 0.8150317655913564, 'reg_alpha': 0.6124409408321532, 'reg_lambda': 1.1698335091957901e-07}. Best is trial 85 with value: 0.42026734889378287.
# [I 2024-11-30 07:50:34,009] Trial 96 finished with value: 0.4667352257942487 and parameters: {'n_estimators': 820, 'learning_rate': 0.06009437055200758, 'num_leaves': 50, 'max_depth': 5, 'min_child_samples': 61, 'subsample': 0.998937013129501, 'colsample_bytree': 0.8508804646200977, 'reg_alpha': 0.20271606705992162, 'reg_lambda': 2.990527945920917e-08}. Best is trial 85 with value: 0.42026734889378287.
# [I 2024-11-30 07:50:37,185] Trial 97 finished with value: 0.4236441393607101 and parameters: {'n_estimators': 920, 'learning_rate': 0.008861094424007435, 'num_leaves': 57, 'max_depth': 5, 'min_child_samples': 59, 'subsample': 0.9552809413435532, 'colsample_bytree': 0.8670959462411207, 'reg_alpha': 1.21975703986883, 'reg_lambda': 6.410224197925398e-08}. Best is trial 85 with value: 0.42026734889378287.
# [I 2024-11-30 07:50:40,219] Trial 98 finished with value: 0.4206118473748063 and parameters: {'n_estimators': 820, 'learning_rate': 0.005986327506184872, 'num_leaves': 47, 'max_depth': 5, 'min_child_samples': 63, 'subsample': 0.9688244278550684, 'colsample_bytree': 0.8194064765030276, 'reg_alpha': 1.6742842704955412, 'reg_lambda': 1.8824310285056574e-07}. Best is trial 85 with value: 0.42026734889378287.
# [I 2024-11-30 07:50:43,308] Trial 99 finished with value: 0.42079924277864017 and parameters: {'n_estimators': 820, 'learning_rate': 0.005943478255165871, 'num_leaves': 39, 'max_depth': 5, 'min_child_samples': 57, 'subsample': 0.9724600441342122, 'colsample_bytree': 0.7874287551226928, 'reg_alpha': 1.642980917124628, 'reg_lambda': 1.7997720723425054e-07}. Best is trial 85 with value: 0.42026734889378287.
# Best trial:
#   Value: 0.42026734889378287
#   Params: {'n_estimators': 720, 'learning_rate': 0.006929010339829607, 'num_leaves': 74, 'max_depth': 5, 'min_child_samples': 63, 'subsample': 0.88349001110643, 'colsample_bytree': 0.9126589206083837, 'reg_alpha': 0.26123018376380863, 'reg_lambda': 1.0785415047975286e-08}

# %%
best_params = {'n_estimators': 720, 'learning_rate': 0.006929010339829607, 'num_leaves': 74, 'max_depth': 5, 'min_child_samples': 63, 'subsample': 0.88349001110643, 'colsample_bytree': 0.9126589206083837, 'reg_alpha': 0.26123018376380863, 'reg_lambda': 1.0785415047975286e-08}

# %%
cross_validator = KFold(n_splits = 5, shuffle=True, random_state = 1000)
model = lgbm.LGBMRegressor(**best_params)
print(cross_validate(model, ft_df, cross_validator))
lgbm.plot_importance(model, importance_type="gain")
# Out:
# {0: 0.3809478238170066, 1: 0.46832327965045345, 2: 0.40218175367441006, 3: 0.4408456219991383, 4: 0.41018912032274185}
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# ## PyTorch Neural Network

# %%
import torch
from torch import nn
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import Dataset, DataLoader, random_split

# %%
batch_size = 1
learning_rate = 0.001
n_epochs = 10
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

split_idx = int(0.8*len(ft_df))
end_idx = len(ft_df)

shuffled_df = ft_df.sample(frac=1, random_state = 404)

X_train = shuffled_df.iloc[0:split_idx].drop('score', axis=1)
X_valid = shuffled_df.iloc[split_idx:end_idx].drop('score', axis=1)
y_train = shuffled_df.iloc[0:split_idx]['score']
y_valid = shuffled_df.iloc[split_idx:end_idx]['score']

X_train = torch.tensor(X_train.values, dtype=torch.float32)
y_train = torch.tensor(y_train.values, dtype=torch.float32).reshape(-1, 1)
X_valid = torch.tensor(X_valid.values, dtype=torch.float32)
y_valid = torch.tensor(y_valid.values, dtype=torch.float32).reshape(-1, 1)

# %%
def learn(X_train, X_valid, y_train, y_valid):

    model = nn.Sequential(nn.Linear(87, 128),
                     nn.LayerNorm(128),
                     nn.ReLU(),
                     nn.Linear(128, 256),
                     nn.LayerNorm(256),
                     nn.ReLU(),
                     nn.Linear(256, 128),
                     nn.LayerNorm(128),
                     nn.ReLU(),
                     nn.Linear(128, 1),).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = ReduceLROnPlateau(optimizer, factor=0.5, patience=2)

    train_loss_history=[]
    val_loss_history=[]
    loss_fn = nn.MSELoss()

    count=0
    for epoch in range(n_epochs):
        print("EPOCH ", epoch+1)
        
        ## TRAIN PHASE :
        model.train()
        losses = []
        for features, labels in zip(X_train, y_train):
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            preds = model(features)
            loss = loss_fn(preds, labels)
            losses.append(float(loss)) 
            loss.backward()
            optimizer.step()
        with tqdm.tqdm(batch_start, unit="batch", mininterval=0, disable=True) as bar:
            bar.set_description(f"Epoch {epoch}")
            for start in bar:
                X_batch = X_train[start:start+batch_size]
                y_batch = y_train[start:start+batch_size]
                optimizer.zero_grad()
                y_pred = model(X_batch)
                loss = loss_fn(y_pred, y_batch)
                losses.append(float(loss))
                loss.backward()
                optimizer.step()
                bar.set_postfix(mse=float(loss))

        avg_loss = np.mean(losses)
        train_loss_history.append(avg_loss)
        if count%2==0:
            print(f"Train Loss : {avg_loss}")
        
        ## VALIDATION PHASE : 
        model.eval()
        losses = []
        for features, labels in zip(X_valid, y_valid):
            features, labels = features.to(device), labels.to(device)
            preds = model(features)
            loss  = loss_fn(preds, labels)
            losses.append(float(loss))

        avg_loss = np.mean(losses)
        val_loss_history.append(avg_loss)
        if count%2==0:
            print(f"Valid Loss : {avg_loss}")
        
        scheduler.step(avg_loss)
        count+=1
    losses_history = {"train" : train_loss_history, "valid" : val_loss_history}
    
    return model, losses_history

# %%
def predict(model, test_data):
    test_ids        = test_data['id'].values
    test_dataset    = WPDataset(data=test_data, phase="test")
    test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False)
        
    model.eval()
    result = np.array([])
    for i, fetres in tqdm(enumerate(test_dataloader)):
        fetres = fetres.to(config.device)
        output = model(fetres)
        result = np.append(result, output.detach().cpu().numpy())

    submission_df = pd.DataFrame(data={"id" : test_ids, "score" : result})
    return submission_df

# %%
mod, losses = learn(X_train, X_valid, y_train, y_valid)
# Out:
# EPOCH  1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 mod, losses = learn(X_train, X_valid, y_train, y_valid)
#
# Cell In[43], line 30, in learn(X_train, X_valid, y_train, y_valid)
#      28 features, labels = features.to(device), labels.to(device)
#      29 optimizer.zero_grad()
# ---> 30 preds = model(features)
#      31 loss = loss_fn(preds, labels)
#      32 losses.append(float(loss))
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x20 and 87x128)
