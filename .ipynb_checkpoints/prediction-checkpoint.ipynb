# %%
# !pip install lightgbm;
# !pip install optuna;

# %%
import json
import gzip
import math
import numpy as np
import random
import statistics
import scipy.stats
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import datetime
from tqdm import tqdm
import sys
import warnings
import re

# %%
warnings.filterwarnings("ignore")
sns.set_style("white")
sns.despine()
plt.rcParams['font.family'] = 'monospace'

# %%
event_df = pd.read_csv('train_logs.csv.zip')
event_df
# Out:
#                id  event_id  down_time  up_time  action_time       activity  \
# 0        001519c8         1       4526     4557           31  Nonproduction
# 1        001519c8         2       4558     4962          404  Nonproduction
# 2        001519c8         3     106571   106571            0  Nonproduction
# 3        001519c8         4     106686   106777           91          Input
# 4        001519c8         5     107196   107323          127          Input
# ...           ...       ...        ...      ...          ...            ...
# 8405893  fff05981      3615    2063944  2064440          496  Nonproduction
# 8405894  fff05981      3616    2064497  2064497            0  Nonproduction
# 8405895  fff05981      3617    2064657  2064765          108        Replace
# 8405896  fff05981      3618    2069186  2069259           73  Nonproduction
# 8405897  fff05981      3619    2070065  2070133           68          Input
#
#         down_event   up_event text_change  cursor_position  word_count
# 0        Leftclick  Leftclick    NoChange                0           0
# 1        Leftclick  Leftclick    NoChange                0           0
# 2            Shift      Shift    NoChange                0           0
# 3                q          q           q                1           1
# 4                q          q           q                2           1
# ...            ...        ...         ...              ...         ...
# 8405893  Leftclick  Leftclick    NoChange             1031         240
# 8405894      Shift      Shift    NoChange             1031         240
# 8405895          q          q      q => q             1031         240
# 8405896  Leftclick  Leftclick    NoChange             1028         240
# 8405897          .          .           .             1029         240
#
# [8405898 rows x 11 columns]

# %%
score_df = pd.read_csv('train_scores.csv')
score_df = score_df.set_index('id')
score_df
# Out:
#           score
# id
# 001519c8    3.5
# 0022f953    3.5
# 0042269b    6.0
# 0059420b    2.0
# 0075873a    4.0
# ...         ...
# ffb8c745    3.5
# ffbef7e5    4.0
# ffccd6fd    1.5
# ffec5b38    5.0
# fff05981    4.0
#
# [2471 rows x 1 columns]

# %% [markdown]
# # Exploratory Data Analysis
#
# I chose this data due to my personal interest in the use of typing patterns as indicators of certain behaviors, and this was a great way to understand the structure / nature of most typing data sets & train models on them.
#
# ## First, let's look at the distribution of scores
#
# We are trying to predict essay scores, so let's examine scores of essays

# %%
x1 = score_df["score"]
# Plot
# kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2}, bins=[0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6])

fig, ax = plt.subplots(figsize=(12,4), dpi= 100)
sns.despine()
ax = sns.histplot(x1, kde=True, line_kws={'linewidth':2},alpha=0.6, bins=[0.75,1.25,1.75,2.25,2.75,3.25,3.75,4.25,4.75,5.25,5.75,6.25])

# %% [markdown]
# ## Let's create some more basic features:
# - `num_events` the number of events
# - `num_deletions` number of deletions
# - `num_words` final word count of essay

# %%
## Functions for basic features:
def num_events(essay_id, df_dict):
    ft_df = df_dict[essay_id]
    return len(ft_df)

def num_deletions(essay_id, df_dict):
    counts =  df_dict[essay_id]['activity'].value_counts()
    if 'Remove/Cut' in counts.index:
        return counts['Remove/Cut']
    else:
        return 0

def num_words(essay_id, df_dict):
    count = df_dict[essay_id]['word_count'].iloc[-1]
    return count

# %%
## Create a dict of essay id to pandas dataframe - easy to get a specific dataframe's essay for feature extraction
essay_events = dict(tuple(event_df.groupby('id')))

# %%
x1 = [num_events(index, essay_events) for index, row in score_df.iterrows()]
x2 = [num_deletions(index, essay_events) for index, row in score_df.iterrows()]
x3 = [num_words(index, essay_events) for index, row in score_df.iterrows()]

# plot
fig, axes = plt.subplots(1, 3, figsize=(10, 3), sharey=True, dpi=100)
sns.histplot(x1 , color="dodgerblue", kde=True, ax=axes[0]).set_xlabel('Number of Events')
sns.histplot(x2 , color="deeppink", kde=True, ax=axes[1]).set_xlabel('Number of Deletions');
sns.histplot(x3 , color="orangered", kde=True, ax=axes[2]).set_xlabel('Number of Words');

# %% [markdown]
# ## These distributions are clearly log-scaled, so let's make features that take the log of both of them
#
# New Features:
#
# - `log_num_events`
# - `log_num_deletions`
# - `log_num_words`

# %%
def log_num_events(essay_id, df_dict):
    return math.log2(num_events(essay_id, df_dict))

def log_num_deletions(essay_id, df_dict):
    return math.log2(num_deletions(essay_id, df_dict) + 1) # offset for log

def log_num_words(essay_id, df_dict):
    return math.log2(num_words(essay_id, df_dict))

# %%
x1 = [log_num_events(index, essay_events) for index, row in score_df.iterrows()]
x2 = [log_num_deletions(index, essay_events) for index, row in score_df.iterrows()]
x3 = [log_num_words(index, essay_events) for index, row in score_df.iterrows()]

# plot
fig, axes = plt.subplots(1, 3, figsize=(10, 3), sharey=True, dpi=100)
sns.histplot(x1 , color="dodgerblue", kde=True, ax=axes[0]).set_xlabel('Log Number of Events')
sns.histplot(x2 , color="deeppink", kde=True, ax=axes[1]).set_xlabel('Log Number of Deletions');
sns.histplot(x3 , color="orangered", kde=True, ax=axes[2]).set_xlabel('Log Number of Words');

# %% [markdown]
# # Prediction
#
# ## Naive Approach (Linear Regression)
#
# The dataset has keystrokes from users, but the keys are anonymized as 'q' so the goal is to use the timestamps / ordering of events to train some model to predict the score of each essay. There are about 2500 users' essays in the dataset and nearly 8.5 million events, so I'll definitely have to drastically reduce dimensionality when I do regular classification. For now, though, we can see if we can fit a regression between # of events and the score for each essay.

# %%
from sklearn import linear_model

# %%
def MSE(predictions, actual):
    return sum((predictions[i] - actual[i])**2 for i in range(len(predictions))) / len(predictions)

# %%
## Train / Valid / Test Split:
seeds = 2004, 1983, 12

splits = [np.split(
    score_df.sample(frac=1, random_state = seed), [int(0.5 * len(score_df))]) for seed in seeds]

train_score_dfs = [split[0] for split in splits]
test_score_dfs = [split[1] for split in splits]

# %%
## All features separate: log and not log

X_trains_num_events = [[[num_events(essay_id, essay_events)] 
                         for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]
X_trains_log_num_events = [[[log_num_events(essay_id, essay_events)] 
                         for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]
X_trains_num_deletions = [[[num_deletions(essay_id, essay_events)] 
                         for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]
X_trains_log_num_deletions = [[[log_num_deletions(essay_id, essay_events)] 
                         for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]
X_trains_num_words = [[[num_words(essay_id, essay_events)] 
                         for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]
X_trains_log_num_words = [[[log_num_words(essay_id, essay_events)] 
                         for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]

y_trains = [[row['score'] for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]


X_tests_num_events = [[[num_events(essay_id, essay_events)] 
                         for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]
X_tests_log_num_events = [[[log_num_events(essay_id, essay_events)] 
                         for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]
X_tests_num_deletions = [[[num_deletions(essay_id, essay_events)] 
                         for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]
X_tests_log_num_deletions = [[[log_num_deletions(essay_id, essay_events)] 
                         for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]
X_tests_num_words = [[[num_words(essay_id, essay_events)] 
                         for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]
X_tests_log_num_words = [[[log_num_words(essay_id, essay_events)] 
                         for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]


y_tests = [[row['score'] for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]

# %%
regs_num_events = [linear_model.LinearRegression().fit(X_train, y_train) for (X_train, y_train) in zip(X_trains_num_events, y_trains)]

regs_log_num_events = [linear_model.LinearRegression().fit(X_train, y_train) for (X_train, y_train) in zip(X_trains_log_num_events, y_trains)]

regs_num_deletions = [linear_model.LinearRegression().fit(X_train, y_train) for (X_train, y_train) in zip(X_trains_num_deletions, y_trains)]

regs_log_num_deletions = [linear_model.LinearRegression().fit(X_train, y_train) for (X_train, y_train) in zip(X_trains_log_num_deletions, y_trains)]

regs_num_words = [linear_model.LinearRegression().fit(X_train, y_train) for (X_train, y_train) in zip(X_trains_num_words, y_trains)]

regs_log_num_words = [linear_model.LinearRegression().fit(X_train, y_train) for (X_train, y_train) in zip(X_trains_log_num_words, y_trains)]

# %%
y_preds_num_events = [reg.predict(X_test) for (reg, X_test) in zip(regs_num_events, X_tests_num_events)]
MSE_num_events = [MSE(y_pred, y_test) for y_pred, y_test in zip(y_preds_num_events, y_tests)]
print(f"MSES for num events: {MSE_num_events}") 

y_preds_log_num_events = [reg.predict(X_test) for (reg, X_test) in zip(regs_log_num_events, X_tests_log_num_events)]
MSE_log_num_events = [MSE(y_pred, y_test) for y_pred, y_test in zip(y_preds_log_num_events, y_tests)]
print(f"MSES for log num events: {MSE_log_num_events}") 

y_preds_num_deletions = [reg.predict(X_test) for (reg, X_test) in zip(regs_num_deletions, X_tests_num_deletions)]
MSE_num_deletions = [MSE(y_pred, y_test) for y_pred, y_test in zip(y_preds_num_deletions, y_tests)]
print(f"MSES for num deletions: {MSE_num_deletions}") 

y_preds_log_num_deletions = [reg.predict(X_test) for (reg, X_test) in zip(regs_log_num_deletions, X_tests_log_num_deletions)]
MSE_log_num_deletions = [MSE(y_pred, y_test) for y_pred, y_test in zip(y_preds_log_num_deletions, y_tests)]
print(f"MSES for log num deletions: {MSE_log_num_deletions}") 

y_preds_num_words = [reg.predict(X_test) for (reg, X_test) in zip(regs_num_words, X_tests_num_words)]
MSE_num_words = [MSE(y_pred, y_test) for y_pred, y_test in zip(y_preds_num_words, y_tests)]
print(f"MSES for num words: {MSE_num_words}") 

y_preds_log_num_words = [reg.predict(X_test) for (reg, X_test) in zip(regs_log_num_words, X_tests_log_num_words)]
MSE_log_num_words = [MSE(y_pred, y_test) for y_pred, y_test in zip(y_preds_log_num_words, y_tests)]
print(f"MSES for log num words: {MSE_log_num_words}")
# Out:
# MSES for num events: [0.6803616180630022, 0.7232688922009521, 0.7238584583279332]
# MSES for log num events: [0.6203263985569867, 0.640463715584686, 0.6334569957435457]
# MSES for num deletions: [0.9623295991847461, 1.001622481505261, 1.0019244005218984]
# MSES for log num deletions: [0.8905918720329442, 0.9228960614109114, 0.9019916447223087]
# MSES for num words: [0.6030279358014377, 0.635038230199783, 0.6420673056192123]
# MSES for log num words: [0.5301670106313389, 0.5577847982455166, 0.5560860065876809]

# %%
## All features combined
X_trains_combined = [[[log_num_events(essay_id, essay_events), log_num_words(essay_id, essay_events)] 
                         for essay_id, row in train_score_df.iterrows()] for train_score_df in train_score_dfs]

X_tests_combined = [[[log_num_events(essay_id, essay_events), log_num_words(essay_id, essay_events)] 
                         for essay_id, row in test_score_df.iterrows()] for test_score_df in test_score_dfs]

regs_combined = [linear_model.LinearRegression().fit(X_train, y_train) for (X_train, y_train) in zip(X_trains_combined, y_trains)]

# %%
y_preds_combined = [reg.predict(X_test) for (reg, X_test) in zip(regs_combined, X_tests_combined)]
MSE_combined = [MSE(y_pred, y_test) for y_pred, y_test in zip(y_preds_combined, y_tests)]
print(f"MSES for log features combined: {MSE_combined}")
# Out:
# MSES for log features combined: [0.5228547055186219, 0.5423025499955366, 0.5400855623894222]

# %%
X_train_final = [[log_num_events(essay_id, essay_events), log_num_deletions(essay_id, essay_events)] for essay_id, row in score_df.iterrows()]
y_train_final = [row['score'] for essay_id, row in score_df.iterrows()]
final_reg = linear_model.LinearRegression().fit(X_train_final, y_train_final)

# %%
# Make predictions on the test data
final_df = pd.read_csv('test_logs.csv')
final_df = final_df.set_index('id')
final_events = dict(tuple(final_df.groupby('id')))

print(final_df)

X_test_final = [[log_num_events(essay_id, final_events), log_num_deletions(essay_id, final_events)] for essay_id, row in final_df.iterrows()]

test_predictions = final_reg.predict(X_test_final)
print(X_test_final)
print(test_predictions)

# Create a submission DataFrame
submission = pd.DataFrame({'id': final_df.index, 'score': test_predictions})

# Remove duplicates from the submission DataFrame
submission.drop_duplicates(subset=['id'], keep='last', inplace=True)

# Save the submission file
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# ### Submitted to Kaggle, MSE: 0.576 RMSE Private / 0.594 RMSE Public
#
# ## Enough is Enough with the linear regressions!
# We need to get organized when we add more features - which means it's time for CV!

# %%
# First thing is to get organized - need to have a way to add any features to a dataframe
# Desired feature is an array of (string, function) representing the name of feature and the function to calculate that feature for an id
def calculate_features(df_dict, desired_features, df):
    feature_df = df.copy()
    for (feature_name, feature_funct) in tqdm(desired_features):
        feature_list = [feature_funct(essay_id, df_dict) for essay_id, row in df.iterrows()]
        feature_df[feature_name] = feature_list
    return feature_df

# %%
from sklearn.model_selection import KFold

# %%
## Now, let's organize our splits with K-Fold Cross Validation
cross_validator = KFold(n_splits = 5, shuffle=True, random_state = 4424)

## Cross validation function to run any model on our folds & give all of the MSES
def cross_validate(model, df, cross_validator):
    X = df.drop('score', axis=1)
    y = df['score']

    mses = {}
    for fold, (train_index, valid_index) in enumerate(cross_validator.split(X, y)):
        X_train = X.iloc[train_index]
        X_valid = X.iloc[valid_index]
        y_train = y.iloc[train_index]
        y_valid = y.iloc[valid_index]

        model.fit(X_train, y_train)

        y_pred = model.predict(X_valid)

        mses[fold] = MSE(y_pred, y_valid)
        #print(mses[fold])

    return mses

# %% [markdown]
# ## Time to engineer some new features!
#
# These are feature recommendations from the paper *{ENTER}ing the Time Series {SPACE}: Uncovering the Writing Process through Keystroke Analyses* (Allen et al.).
#
# Using big words is probably indicative of high vocabulary. Creating a feature that weighs big words a certain way can lead to a stronger model.
# - `avg_word_length`, `max_word_length`, `std_word_length`, `skew_word_length`, `kurtosis_word_length`
# - `words_longer_4`, `words_longer_5`, `words_longer_6`, `words_longer_7`, `words_longer_8`, `words_longer_9`
# Experienced writers can probably type fast. People pause while writing, but each pause while writing is probably no more than a second, so let's calculate typing speed & keep all pauses out of influencing this average.
# - `avg_typing_speed`, `std_typing_speed`, `skew_typing_speed`, `kurtosis_typing_speed`
# A good writer probably also takes certain amount of pauses between writing, so let's calculate the following:
# - `pauses_0.5_second`, `pauses_1_second`, `pauses_1.5_second`, `pauses_2_second`, `pauses_2.5_second`, `pauses_3_second`
# - `comma_count`, `period_count`, `question_mark_count`, `apostrophe_count`, `quote_count`, `exclamation_count`

# %%
def avg_word_length(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return np.mean([len(word) for word in word_list(essay_df)])

def max_word_length(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return max([len(word) for word in word_list(essay_df)])

def std_word_length(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return np.std([len(word) for word in word_list(essay_df)])

def skew_word_length(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return scipy.stats.skew([len(word) for word in word_list(essay_df)])

def kurtosis_word_length(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return scipy.stats.kurtosis([len(word) for word in word_list(essay_df)])

## To do this efficiently, we should separate each essay in into words just once and make a column, calculate these stats, then delete the column

def words_longer_4(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return sum([len(word) > 4 for word in word_list(essay_df)])

def words_longer_5(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return sum([len(word) > 5 for word in word_list(essay_df)])

def words_longer_6(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return sum([len(word) > 6 for word in word_list(essay_df)])

def words_longer_7(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return sum([len(word) > 7 for word in word_list(essay_df)])

def words_longer_8(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return sum([len(word) > 8 for word in word_list(essay_df)])

def words_longer_9(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return sum([len(word) > 9 for word in word_list(essay_df)])


def word_list(essay_df):
    inputs_df = essay_df[essay_df['activity'] == 'Input']
    rough_essay = "".join(list(inputs_df['text_change']))
    return re.findall(r'q+', rough_essay)

# %%
def avg_typing_speed(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return np.mean(typing_gaps(essay_df))
    
def std_typing_speed(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return np.std(typing_gaps(essay_df))

def skew_typing_speed(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return scipy.stats.skew(typing_gaps(essay_df))

def kurtosis_typing_speed(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return scipy.stats.kurtosis(typing_gaps(essay_df))

def typing_gaps(essay_df):
    down_times = list(essay_df['down_time'])
    typing_gaps = [down_times[i] - down_times[i-1] for i in range(1,len(down_times))]
    typing_gaps_cleaned = [typing_gap for typing_gap in typing_gaps if typing_gap < 1000]
    return typing_gaps_cleaned

# %%
def pause_0_5_second(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return pauses(essay_df, 500)

def pause_1_second(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return pauses(essay_df, 1000)

def pause_1_5_second(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return pauses(essay_df, 1500)

def pause_2_second(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return pauses(essay_df, 2000)

def pause_2_5_second(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return pauses(essay_df, 2500)

def pause_3_second(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return pauses(essay_df, 3000)

def pauses(essay_df, threshold):
    down_times = list(essay_df['down_time'])
    typing_gaps = [down_times[i] - down_times[i-1] for i in range(1,len(down_times))]
    return sum(typing_gap > threshold for typing_gap in typing_gaps)

# %%
def comma_count(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return essay_df['up_event'].value_counts()[","] if "," in essay_df['up_event'].value_counts() else 0

def period_count(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return essay_df['up_event'].value_counts()["."] if "." in essay_df['up_event'].value_counts() else 0

def quote_count(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return essay_df['up_event'].value_counts()['"'] if '"' in essay_df['up_event'].value_counts() else 0

def apostrophe_count(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return essay_df['up_event'].value_counts()["'"] if "'" in essay_df['up_event'].value_counts() else 0

def question_count(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return essay_df['up_event'].value_counts()["?"] if "?" in essay_df['up_event'].value_counts() else 0

def exclamation_count(essay_id, df_dict):
    essay_df = df_dict[essay_id]
    return essay_df['up_event'].value_counts()["!"] if "!" in essay_df['up_event'].value_counts() else 0

# %%
desired_features = [('num_deletions', num_deletions), ('num_events', num_events), 
                    ('num_words', num_words), ('avg_word_length', avg_word_length ), ('max_word_length', max_word_length), 
                    ('std_word_length', std_word_length), ('skew_word_length', skew_word_length), 
                    ('kurtosis_word_length', kurtosis_word_length), ('words_longer_4', words_longer_4), 
                    ('words_longer_5', words_longer_5), ('words_longer_6', words_longer_6), ('words_longer_7', words_longer_7),
                    ('words_longer_8', words_longer_8), ('words_longer_9', words_longer_9),
                    ('avg_typing_speed', avg_typing_speed), ('skew_typing_speed', skew_typing_speed),
                    ('std_typing_speed', std_typing_speed), ('kurtosis_typing_speed', kurtosis_typing_speed),
                    ('pause_0_5_second', pause_0_5_second), ('pause_1_second', pause_1_second), ('pause_1_5_second', pause_1_5_second), 
                    ('pause_2_second', pause_2_second), ('pause_2_5_second', pause_2_5_second), ('pause_3_second', pause_3_second),
                    ('comma_count', comma_count), ('period_count', period_count), ('quote_count', quote_count), 
                    ('apostrophe_count', apostrophe_count), ('question_count', question_count), ('exclamation_count', exclamation_count) 
                   ]
ft_df = calculate_features(essay_events, desired_features, score_df)
# Out:
# 100%|██████████| 36/36 [01:34<00:00,  2.62s/it]

# %%
fig, axes = plt.subplots(7, 5, figsize=(20, 25), sharey=False, dpi=100)

axes = axes.flatten()

palette = sns.color_palette("husl", len(ft_df.columns))

for idx, column in tqdm(enumerate(ft_df.columns)):
    sns.histplot(ft_df[column], color=palette[idx], kde=True, ax=axes[idx])
    axes[idx].set_xlabel(f'{column}')

for j in range(len(ft_df.columns), len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 31it [00:18,  1.69it/s]

# %%
correlation_matrix = ft_df.corr()
plt.figure(figsize=(12, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## Linear Regression with the new features
#
# First, we should take the log of all features and put it in a new dataframe

# %%
log_ft_df = ft_df.copy()
    
for col in ft_df.select_dtypes(include=[np.number]).columns:
    shifted_col = ft_df[col] - ft_df[col].min() + 1e-6
    log_ft_df[f'log_{col}'] = np.log(shifted_col)
log_ft_df = log_ft_df.drop('log_score', axis = 1)

# %%
log_ft_df
# Out:
#           score  num_deletions  num_events  num_words  avg_word_length  \
# id
# 001519c8    3.5            417        2557        255         4.947853
# 0022f953    3.5            260        2454        320         4.090659
# 0042269b    6.0            439        4136        404         5.267273
# 0059420b    2.0            151        1556        206         4.417021
# 0075873a    4.0            517        2531        252         4.492711
# ...         ...            ...         ...        ...              ...
# ffb8c745    3.5            960        4739        273         4.722591
# ffbef7e5    4.0             60        2604        438         4.054113
# ffccd6fd    1.5             88        3063        201         4.465438
# ffec5b38    5.0            276        3242        413         5.055675
# fff05981    4.0            310        3619        240         4.937500
#
#           max_word_length  std_word_length  skew_word_length  \
# id
# 001519c8               14         2.786973          0.827438
# 0022f953               22         2.452857          2.413930
# 0042269b               17         2.960869          0.952503
# 0059420b               16         2.714133          1.556064
# 0075873a               20         2.763639          1.415424
# ...                   ...              ...               ...
# ffb8c745               14         2.742151          0.976979
# ffbef7e5               13         2.182004          0.829613
# ffccd6fd               14         2.532727          1.024942
# ffec5b38               18         3.122946          1.322251
# fff05981               22         3.289163          1.207315
#
#           kurtosis_word_length  words_longer_4  ...  avg_typing_speed  \
# id                                              ...
# 001519c8             -0.049868             154  ...        191.752467
# 0022f953             10.364904             116  ...        204.746626
# 0042269b              0.505729             275  ...        128.186949
# 0059420b              3.035786              89  ...        276.027544
# 0075873a              3.009695             134  ...        191.495819
# ...                        ...             ...  ...               ...
# ffb8c745              0.433473             251  ...        150.037405
# ffbef7e5              0.670496             158  ...        280.717284
# ffccd6fd              0.906297              91  ...        210.667254
# ffec5b38              1.874763             218  ...        204.355026
# fff05981              1.788361             178  ...        223.820474
#
#           skew_typing_speed  std_typing_speed  kurtosis_typing_speed  \
# id
# 001519c8           2.318082        162.628704               5.783103
# 0022f953           2.343222        168.221909               5.768109
# 0042269b           3.822477        122.898182              17.112811
# 0059420b           1.000082        214.720553               0.471059
# 0075873a           1.953751        146.650059               5.140510
# ...                     ...               ...                    ...
# ffb8c745           3.151022        131.307351              12.292701
# ffbef7e5           1.516782        152.033856               3.608851
# ffccd6fd           1.268971        203.953535               1.451127
# ffec5b38           2.232826        153.263791               6.129929
# fff05981           2.071887        187.547088               4.245710
#
#           pause_0_5_second  pause_1_second  pause_1_5_second  pause_2_second  \
# id
# 001519c8               385             225               164             135
# 0022f953               330             155               102              85
# 0042269b               291             166               116              84
# 0059420b               464             248               139              93
# 0075873a               246             138               104              92
# ...                    ...             ...               ...             ...
# ffb8c745               276             113                64              46
# ffbef7e5               354             173               121              92
# ffccd6fd               518             221               131              91
# ffec5b38               315             137                97              70
# fff05981               596             287               179             122
#
#           pause_2_5_second  pause_3_second
# id
# 001519c8               118             104
# 0022f953                73              63
# 0042269b                69              56
# 0059420b                73              59
# 0075873a                78              73
# ...                    ...             ...
# ffb8c745                41              31
# ffbef7e5                77              69
# ffccd6fd                72              60
# ffec5b38                53              49
# fff05981               100              84
#
# [2471 rows x 25 columns]

# %%
cross_validator = KFold(n_splits = 5, shuffle=True, random_state = 1)

model = linear_model.LinearRegression()
cross_validator = KFold(n_splits = 5, shuffle=True, random_state = 1)
print(cross_validate(model, log_ft_df, cross_validator))
cross_validator = KFold(n_splits = 2, shuffle=True, random_state = 10)
print(cross_validate(model, log_ft_df, cross_validator))
cross_validator = KFold(n_splits = 10, shuffle=True, random_state = 100)
print(cross_validate(model, log_ft_df, cross_validator))
# Out:
# {0: 1.6834151156783805, 1: 3741729.182231859, 2: 0.4683179820037432, 3: 0.376841210048584, 4: 0.6277225358859855}
# {0: 0.47583245431398397, 1: 97808.29000374032}
# {0: 2.614880695688675, 1: 0.3678134985106201, 2: 0.4665660164995959, 3: 0.3528807828850716, 4: 0.4292031297814149, 5: 0.4427762038497815, 6: 0.504297287560392, 7: 4938798.802686289, 8: 0.39546436615966074, 9: 0.46785729057638337}

# %% [markdown]
# I wonder what that outlier is! That's so weird. Either way, linear regression doesn't seem like it will work too well for our purposes.

# %% [markdown]
# ## LGBM

# %%
import lightgbm as lgbm
import optuna

# %%
def objective(trial):
    # Define hyperparameter search space
    param = {
        "n_estimators": trial.suggest_int("n_estimators", 20, 920, step=100),
    "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.1, log=True), 
    "num_leaves": trial.suggest_int("num_leaves", 31, 128),  # Increase num_leaves
    "max_depth": trial.suggest_int("max_depth", 5, 15),
    "min_child_samples": trial.suggest_int("min_child_samples", 20, 100),
    "subsample": trial.suggest_float("subsample", 0.6, 1.0),
    "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
    "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 10.0, log=True),
    "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 10.0, log=True),
    }


    model = lgbm.LGBMRegressor(
        **param,
        random_state = 2004,
        verbose = -1
    )

    
    
    mse = np.mean(list(cross_validate(model, ft_df, cross_validator).values()))
    return mse

# Optimize hyperparameters
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=100)

# Print best hyperparameters
print("Best trial:")
print(f"  Value: {study.best_trial.value}")
print(f"  Params: {study.best_trial.params}")
# Out:
# [I 2024-11-30 07:56:24,678] A new study created in memory with name: no-name-c81879ca-ce69-4a91-a67a-4345cf16c7af
# [I 2024-11-30 07:56:27,174] Trial 0 finished with value: 0.5182128026550077 and parameters: {'n_estimators': 320, 'learning_rate': 0.0030710966276194917, 'num_leaves': 101, 'max_depth': 7, 'min_child_samples': 39, 'subsample': 0.7360414100694344, 'colsample_bytree': 0.9671941035036178, 'reg_alpha': 1.4304742506596415e-08, 'reg_lambda': 3.183115813919449e-08}. Best is trial 0 with value: 0.5182128026550077.
# [I 2024-11-30 07:56:27,732] Trial 1 finished with value: 0.4268881146222164 and parameters: {'n_estimators': 120, 'learning_rate': 0.023617650643106874, 'num_leaves': 43, 'max_depth': 6, 'min_child_samples': 85, 'subsample': 0.6634428995647172, 'colsample_bytree': 0.823335114442918, 'reg_alpha': 0.00017915416496989855, 'reg_lambda': 3.0514585373386656e-06}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:29,254] Trial 2 finished with value: 0.441077106325937 and parameters: {'n_estimators': 320, 'learning_rate': 0.006167511935214806, 'num_leaves': 122, 'max_depth': 7, 'min_child_samples': 75, 'subsample': 0.7496317415857088, 'colsample_bytree': 0.9462551413072453, 'reg_alpha': 5.9825280871508415e-05, 'reg_lambda': 0.2843968908623975}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:31,197] Trial 3 finished with value: 0.4283601938454262 and parameters: {'n_estimators': 520, 'learning_rate': 0.014294662645723724, 'num_leaves': 71, 'max_depth': 5, 'min_child_samples': 38, 'subsample': 0.6703164258848676, 'colsample_bytree': 0.8774809669192637, 'reg_alpha': 2.4664016522940357e-05, 'reg_lambda': 2.5364659265049083e-08}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:31,761] Trial 4 finished with value: 0.4401525740885165 and parameters: {'n_estimators': 120, 'learning_rate': 0.016234466185985015, 'num_leaves': 40, 'max_depth': 7, 'min_child_samples': 76, 'subsample': 0.7736500049254023, 'colsample_bytree': 0.540822306266534, 'reg_alpha': 1.1249816871202522e-08, 'reg_lambda': 5.380989070403529e-05}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:34,404] Trial 5 finished with value: 0.45445003666376127 and parameters: {'n_estimators': 720, 'learning_rate': 0.03534432623018475, 'num_leaves': 55, 'max_depth': 6, 'min_child_samples': 22, 'subsample': 0.699212107033007, 'colsample_bytree': 0.5576504693219307, 'reg_alpha': 1.618957562717334e-05, 'reg_lambda': 5.4628048396828404e-08}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:35,888] Trial 6 finished with value: 0.683260680499386 and parameters: {'n_estimators': 320, 'learning_rate': 0.0014898703024998614, 'num_leaves': 55, 'max_depth': 9, 'min_child_samples': 71, 'subsample': 0.9522501482966962, 'colsample_bytree': 0.8661439253599746, 'reg_alpha': 1.1642522317897341, 'reg_lambda': 5.8156821795382534e-05}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:36,705] Trial 7 finished with value: 0.4427777321025627 and parameters: {'n_estimators': 220, 'learning_rate': 0.008870602651417123, 'num_leaves': 44, 'max_depth': 15, 'min_child_samples': 91, 'subsample': 0.7678399800298688, 'colsample_bytree': 0.5188828591303414, 'reg_alpha': 7.058471295278048e-07, 'reg_lambda': 0.07296706144290842}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:38,069] Trial 8 finished with value: 0.43671384659020884 and parameters: {'n_estimators': 320, 'learning_rate': 0.03743805160748573, 'num_leaves': 33, 'max_depth': 8, 'min_child_samples': 56, 'subsample': 0.7552397991775336, 'colsample_bytree': 0.754874268170918, 'reg_alpha': 5.359986685081544e-07, 'reg_lambda': 5.1083605022405045}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:39,302] Trial 9 finished with value: 0.460597139580704 and parameters: {'n_estimators': 220, 'learning_rate': 0.09337831183297858, 'num_leaves': 36, 'max_depth': 10, 'min_child_samples': 48, 'subsample': 0.8878533017218946, 'colsample_bytree': 0.9644706693374521, 'reg_alpha': 0.0029955951381897133, 'reg_lambda': 0.6236567269537422}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:39,514] Trial 10 finished with value: 0.4766939993322107 and parameters: {'n_estimators': 20, 'learning_rate': 0.06534010122037841, 'num_leaves': 82, 'max_depth': 13, 'min_child_samples': 95, 'subsample': 0.60670798552759, 'colsample_bytree': 0.694292484228211, 'reg_alpha': 0.007244486232453589, 'reg_lambda': 1.9415287502503976e-06}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:41,687] Trial 11 finished with value: 0.43334153862850355 and parameters: {'n_estimators': 620, 'learning_rate': 0.018366018160583603, 'num_leaves': 72, 'max_depth': 5, 'min_child_samples': 29, 'subsample': 0.6057024840756479, 'colsample_bytree': 0.8251095488930926, 'reg_alpha': 0.0009986676675763978, 'reg_lambda': 1.2525033362902628e-06}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:44,706] Trial 12 finished with value: 0.43923915269716146 and parameters: {'n_estimators': 920, 'learning_rate': 0.019620781337024665, 'num_leaves': 76, 'max_depth': 5, 'min_child_samples': 38, 'subsample': 0.6753865688862899, 'colsample_bytree': 0.8342433052933613, 'reg_alpha': 0.08452948343838551, 'reg_lambda': 1.0167990655794542e-06}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:47,291] Trial 13 finished with value: 0.42845816912202206 and parameters: {'n_estimators': 520, 'learning_rate': 0.004641691667091946, 'num_leaves': 62, 'max_depth': 11, 'min_child_samples': 63, 'subsample': 0.8457252469037008, 'colsample_bytree': 0.7066773714588019, 'reg_alpha': 5.376414124988632e-06, 'reg_lambda': 0.0028556553658399364}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:48,782] Trial 14 finished with value: 0.4371812563727894 and parameters: {'n_estimators': 520, 'learning_rate': 0.03567180923305025, 'num_leaves': 93, 'max_depth': 5, 'min_child_samples': 84, 'subsample': 0.6640391316347912, 'colsample_bytree': 0.8839688916929531, 'reg_alpha': 0.0001987557593031857, 'reg_lambda': 1.5121812240027645e-07}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:52,804] Trial 15 finished with value: 0.43637697822718424 and parameters: {'n_estimators': 820, 'learning_rate': 0.011666648576192424, 'num_leaves': 62, 'max_depth': 11, 'min_child_samples': 58, 'subsample': 0.6443205762754132, 'colsample_bytree': 0.7698162306026501, 'reg_alpha': 0.07378216672506367, 'reg_lambda': 1.1523433413410633e-08}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:53,012] Trial 16 finished with value: 0.9902371511690644 and parameters: {'n_estimators': 20, 'learning_rate': 0.0027345421548138995, 'num_leaves': 109, 'max_depth': 9, 'min_child_samples': 99, 'subsample': 0.8356595581637787, 'colsample_bytree': 0.623535444462209, 'reg_alpha': 1.7468817946172505e-06, 'reg_lambda': 3.660867393288324e-05}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:54,961] Trial 17 finished with value: 0.42778179827064405 and parameters: {'n_estimators': 620, 'learning_rate': 0.027085475303718878, 'num_leaves': 47, 'max_depth': 6, 'min_child_samples': 47, 'subsample': 0.712918599973521, 'colsample_bytree': 0.8001616684568946, 'reg_alpha': 9.72968581386016, 'reg_lambda': 0.002732484463674319}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:56:57,978] Trial 18 finished with value: 0.4336466296939987 and parameters: {'n_estimators': 720, 'learning_rate': 0.02680565242090331, 'num_leaves': 49, 'max_depth': 8, 'min_child_samples': 47, 'subsample': 0.7031233448930584, 'colsample_bytree': 0.7984637715369572, 'reg_alpha': 7.033569737159144, 'reg_lambda': 0.0024685849314408743}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:57:00,117] Trial 19 finished with value: 0.46597252365939806 and parameters: {'n_estimators': 420, 'learning_rate': 0.060394724042044885, 'num_leaves': 50, 'max_depth': 13, 'min_child_samples': 65, 'subsample': 0.8091839292300991, 'colsample_bytree': 0.6870839140190277, 'reg_alpha': 0.11216068936090194, 'reg_lambda': 0.0016582933647333576}. Best is trial 1 with value: 0.4268881146222164.
# [I 2024-11-30 07:57:02,382] Trial 20 finished with value: 0.4228008180297952 and parameters: {'n_estimators': 620, 'learning_rate': 0.008040206668815006, 'num_leaves': 31, 'max_depth': 6, 'min_child_samples': 85, 'subsample': 0.9876858229220695, 'colsample_bytree': 0.9127188537843491, 'reg_alpha': 0.014180412900195767, 'reg_lambda': 0.02143572899313018}. Best is trial 20 with value: 0.4228008180297952.
# [I 2024-11-30 07:57:04,646] Trial 21 finished with value: 0.4220534267570435 and parameters: {'n_estimators': 620, 'learning_rate': 0.008280309183309275, 'num_leaves': 34, 'max_depth': 6, 'min_child_samples': 85, 'subsample': 0.9671356550334175, 'colsample_bytree': 0.9152305059254991, 'reg_alpha': 0.015248734130384295, 'reg_lambda': 0.01575355854439695}. Best is trial 21 with value: 0.4220534267570435.
# [I 2024-11-30 07:57:07,251] Trial 22 finished with value: 0.42161530388610347 and parameters: {'n_estimators': 720, 'learning_rate': 0.007770664258275212, 'num_leaves': 31, 'max_depth': 6, 'min_child_samples': 84, 'subsample': 0.997214935646854, 'colsample_bytree': 0.9255036664928165, 'reg_alpha': 0.009957024103473374, 'reg_lambda': 0.03197337471331195}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:10,136] Trial 23 finished with value: 0.42418738197331596 and parameters: {'n_estimators': 720, 'learning_rate': 0.007789944326402599, 'num_leaves': 32, 'max_depth': 8, 'min_child_samples': 84, 'subsample': 0.9981484950897274, 'colsample_bytree': 0.9275971046225462, 'reg_alpha': 0.015919741637267473, 'reg_lambda': 0.022849148982249674}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:13,514] Trial 24 finished with value: 0.42393818664855665 and parameters: {'n_estimators': 920, 'learning_rate': 0.0046188841802425025, 'num_leaves': 32, 'max_depth': 6, 'min_child_samples': 90, 'subsample': 0.9347474035688996, 'colsample_bytree': 0.9999200070944849, 'reg_alpha': 0.6866194231567742, 'reg_lambda': 0.018883446539924534}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:16,222] Trial 25 finished with value: 0.42527483836500296 and parameters: {'n_estimators': 620, 'learning_rate': 0.006046825070719661, 'num_leaves': 40, 'max_depth': 7, 'min_child_samples': 78, 'subsample': 0.9937138099763878, 'colsample_bytree': 0.9136555754995856, 'reg_alpha': 0.0010360352249912325, 'reg_lambda': 1.3644231486770988}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:20,314] Trial 26 finished with value: 0.4335102375010946 and parameters: {'n_estimators': 820, 'learning_rate': 0.0028653213029933363, 'num_leaves': 31, 'max_depth': 9, 'min_child_samples': 68, 'subsample': 0.9555830920131203, 'colsample_bytree': 0.9989386733415191, 'reg_alpha': 0.01683717481848397, 'reg_lambda': 0.0782968060876522}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:23,047] Trial 27 finished with value: 0.42876107593687385 and parameters: {'n_estimators': 820, 'learning_rate': 0.011996331386508718, 'num_leaves': 62, 'max_depth': 6, 'min_child_samples': 89, 'subsample': 0.9075077530352605, 'colsample_bytree': 0.9098883556755799, 'reg_alpha': 0.4053438801380831, 'reg_lambda': 0.00044668205018806264}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:25,358] Trial 28 finished with value: 0.5047304218843705 and parameters: {'n_estimators': 620, 'learning_rate': 0.0018075229486756268, 'num_leaves': 85, 'max_depth': 8, 'min_child_samples': 99, 'subsample': 0.974939068200558, 'colsample_bytree': 0.8935300850648443, 'reg_alpha': 0.004881556871731435, 'reg_lambda': 0.014163635970919521}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:27,291] Trial 29 finished with value: 0.459026324144614 and parameters: {'n_estimators': 420, 'learning_rate': 0.0037376204798543165, 'num_leaves': 54, 'max_depth': 7, 'min_child_samples': 80, 'subsample': 0.906468496193779, 'colsample_bytree': 0.94884071723414, 'reg_alpha': 0.015967664666259245, 'reg_lambda': 0.16571539351996917}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:30,231] Trial 30 finished with value: 0.5938886115685611 and parameters: {'n_estimators': 720, 'learning_rate': 0.0010225121690682574, 'num_leaves': 39, 'max_depth': 5, 'min_child_samples': 71, 'subsample': 0.8733138500293447, 'colsample_bytree': 0.8529761518798674, 'reg_alpha': 0.0015191319007524678, 'reg_lambda': 6.262110700422025}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:33,520] Trial 31 finished with value: 0.42442801684436493 and parameters: {'n_estimators': 920, 'learning_rate': 0.005921241719105887, 'num_leaves': 31, 'max_depth': 6, 'min_child_samples': 89, 'subsample': 0.9377213074422734, 'colsample_bytree': 0.9992186526055481, 'reg_alpha': 0.9367446119165608, 'reg_lambda': 0.016051052376555183}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:36,837] Trial 32 finished with value: 0.42739621181629756 and parameters: {'n_estimators': 920, 'learning_rate': 0.008212302739536256, 'num_leaves': 38, 'max_depth': 7, 'min_child_samples': 91, 'subsample': 0.9348821296382139, 'colsample_bytree': 0.9791204475528622, 'reg_alpha': 0.23366357253703268, 'reg_lambda': 0.010865965002863407}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:40,303] Trial 33 finished with value: 0.425791323788747 and parameters: {'n_estimators': 820, 'learning_rate': 0.0042346867122577715, 'num_leaves': 44, 'max_depth': 7, 'min_child_samples': 82, 'subsample': 0.972683618210405, 'colsample_bytree': 0.9511985265136507, 'reg_alpha': 0.04393188319275391, 'reg_lambda': 1.1111249265794358}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:42,902] Trial 34 finished with value: 0.42431130105841175 and parameters: {'n_estimators': 720, 'learning_rate': 0.005541417022035462, 'num_leaves': 126, 'max_depth': 6, 'min_child_samples': 94, 'subsample': 0.9222470939084978, 'colsample_bytree': 0.9232974779195273, 'reg_alpha': 0.0003570984841560268, 'reg_lambda': 0.0004064550109745665}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:44,926] Trial 35 finished with value: 0.422832806537121 and parameters: {'n_estimators': 620, 'learning_rate': 0.009813400796925515, 'num_leaves': 38, 'max_depth': 5, 'min_child_samples': 86, 'subsample': 0.972039673580462, 'colsample_bytree': 0.9684277263172089, 'reg_alpha': 1.4332388009975867, 'reg_lambda': 0.04927694053477307}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:46,695] Trial 36 finished with value: 0.4218538146662835 and parameters: {'n_estimators': 520, 'learning_rate': 0.012088028395132597, 'num_leaves': 43, 'max_depth': 5, 'min_child_samples': 73, 'subsample': 0.9715349326475557, 'colsample_bytree': 0.8549636123942717, 'reg_alpha': 2.2410212311419735, 'reg_lambda': 0.07678836601948337}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:48,430] Trial 37 finished with value: 0.4236513223088342 and parameters: {'n_estimators': 520, 'learning_rate': 0.014150164668131102, 'num_leaves': 113, 'max_depth': 5, 'min_child_samples': 74, 'subsample': 0.99215727859297, 'colsample_bytree': 0.8618955785267536, 'reg_alpha': 3.3386480386930595, 'reg_lambda': 0.23393093540980103}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:50,253] Trial 38 finished with value: 0.42622034953939664 and parameters: {'n_estimators': 420, 'learning_rate': 0.007448615626574451, 'num_leaves': 44, 'max_depth': 6, 'min_child_samples': 74, 'subsample': 0.9591162460594682, 'colsample_bytree': 0.890525605291582, 'reg_alpha': 6.804254999908994e-05, 'reg_lambda': 0.00016111327177320624}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:52,261] Trial 39 finished with value: 0.4248290631881109 and parameters: {'n_estimators': 520, 'learning_rate': 0.011222365391447497, 'num_leaves': 52, 'max_depth': 7, 'min_child_samples': 79, 'subsample': 0.8766532428540568, 'colsample_bytree': 0.8456487006876068, 'reg_alpha': 9.572328336287245e-08, 'reg_lambda': 0.006141679806260727}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:54,168] Trial 40 finished with value: 0.4259279301966843 and parameters: {'n_estimators': 620, 'learning_rate': 0.01494836651988111, 'num_leaves': 66, 'max_depth': 5, 'min_child_samples': 68, 'subsample': 0.912423763639689, 'colsample_bytree': 0.8033097431038526, 'reg_alpha': 0.0004021356818477498, 'reg_lambda': 0.46034370923204243}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:56,204] Trial 41 finished with value: 0.42303486857548844 and parameters: {'n_estimators': 620, 'learning_rate': 0.009564038211325192, 'num_leaves': 37, 'max_depth': 5, 'min_child_samples': 86, 'subsample': 0.9746999827238781, 'colsample_bytree': 0.9342453625775694, 'reg_alpha': 2.243158335281953, 'reg_lambda': 0.10678937440482773}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:57:58,840] Trial 42 finished with value: 0.4226023939752436 and parameters: {'n_estimators': 720, 'learning_rate': 0.007167459181633518, 'num_leaves': 43, 'max_depth': 6, 'min_child_samples': 86, 'subsample': 0.9760630263253176, 'colsample_bytree': 0.9646555229906334, 'reg_alpha': 0.3177525566539782, 'reg_lambda': 0.03308320664806548}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:01,395] Trial 43 finished with value: 0.4231973821362276 and parameters: {'n_estimators': 720, 'learning_rate': 0.007088459633488161, 'num_leaves': 44, 'max_depth': 6, 'min_child_samples': 94, 'subsample': 0.9990808815963517, 'colsample_bytree': 0.9042765977662688, 'reg_alpha': 0.2220418569297139, 'reg_lambda': 0.0010846084015422375}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:03,136] Trial 44 finished with value: 0.4312075692621942 and parameters: {'n_estimators': 520, 'learning_rate': 0.02172662150263258, 'num_leaves': 58, 'max_depth': 6, 'min_child_samples': 82, 'subsample': 0.9544355415794255, 'colsample_bytree': 0.8755333073610446, 'reg_alpha': 0.0243600432697492, 'reg_lambda': 0.04275135564456021}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:05,799] Trial 45 finished with value: 0.43069265318784566 and parameters: {'n_estimators': 720, 'learning_rate': 0.01375502084055737, 'num_leaves': 35, 'max_depth': 7, 'min_child_samples': 77, 'subsample': 0.9813247393797525, 'colsample_bytree': 0.9323026163879434, 'reg_alpha': 0.005294224951287053, 'reg_lambda': 0.005298496036190021}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:09,698] Trial 46 finished with value: 0.430623448624243 and parameters: {'n_estimators': 820, 'learning_rate': 0.0032401182546561826, 'num_leaves': 47, 'max_depth': 8, 'min_child_samples': 72, 'subsample': 0.9449052888006442, 'colsample_bytree': 0.9634437490287592, 'reg_alpha': 0.18636455239113578, 'reg_lambda': 2.817596191155885}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:11,457] Trial 47 finished with value: 0.43731317009661363 and parameters: {'n_estimators': 420, 'learning_rate': 0.005103107246283349, 'num_leaves': 42, 'max_depth': 6, 'min_child_samples': 87, 'subsample': 0.9237668960105448, 'colsample_bytree': 0.8716986742675777, 'reg_alpha': 0.04145558626762774, 'reg_lambda': 0.15135214877855438}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:15,067] Trial 48 finished with value: 0.4232049974251334 and parameters: {'n_estimators': 620, 'learning_rate': 0.006533859172304692, 'num_leaves': 35, 'max_depth': 15, 'min_child_samples': 54, 'subsample': 0.9628242247255071, 'colsample_bytree': 0.7254480117627192, 'reg_alpha': 0.002581059466973503, 'reg_lambda': 1.346178610074286e-05}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:17,181] Trial 49 finished with value: 0.4241717614227495 and parameters: {'n_estimators': 520, 'learning_rate': 0.009257768933882382, 'num_leaves': 57, 'max_depth': 13, 'min_child_samples': 95, 'subsample': 0.8929421025802072, 'colsample_bytree': 0.819709362374395, 'reg_alpha': 0.35023836616890713, 'reg_lambda': 0.034905727777784695}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:18,680] Trial 50 finished with value: 0.5762670266458093 and parameters: {'n_estimators': 320, 'learning_rate': 0.0023801816014140972, 'num_leaves': 42, 'max_depth': 10, 'min_child_samples': 81, 'subsample': 0.9824386757791632, 'colsample_bytree': 0.9438020504117218, 'reg_alpha': 0.09340317165346211, 'reg_lambda': 0.007013684562960238}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:20,716] Trial 51 finished with value: 0.42260291644215364 and parameters: {'n_estimators': 620, 'learning_rate': 0.009878731811157454, 'num_leaves': 37, 'max_depth': 5, 'min_child_samples': 86, 'subsample': 0.9674244813148701, 'colsample_bytree': 0.9735456241877227, 'reg_alpha': 3.5433856154325656, 'reg_lambda': 0.05092790233037255}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:23,118] Trial 52 finished with value: 0.42369862770189004 and parameters: {'n_estimators': 720, 'learning_rate': 0.011431782035817751, 'num_leaves': 34, 'max_depth': 5, 'min_child_samples': 76, 'subsample': 0.9436105045330794, 'colsample_bytree': 0.9771381431629187, 'reg_alpha': 5.818428800418871, 'reg_lambda': 0.47088929431430554}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:25,088] Trial 53 finished with value: 0.42727272623097123 and parameters: {'n_estimators': 620, 'learning_rate': 0.01720310521330608, 'num_leaves': 47, 'max_depth': 5, 'min_child_samples': 84, 'subsample': 0.9633349836022305, 'colsample_bytree': 0.9561000654669979, 'reg_alpha': 2.2053911090889833, 'reg_lambda': 0.05705204151046938}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:26,903] Trial 54 finished with value: 0.42497251089989546 and parameters: {'n_estimators': 520, 'learning_rate': 0.012697313858720565, 'num_leaves': 36, 'max_depth': 6, 'min_child_samples': 96, 'subsample': 0.9990597396558862, 'colsample_bytree': 0.9043427650492052, 'reg_alpha': 0.8032025494932127, 'reg_lambda': 0.10571512170981395}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:29,567] Trial 55 finished with value: 0.424023226121612 and parameters: {'n_estimators': 720, 'learning_rate': 0.008943008702195533, 'num_leaves': 94, 'max_depth': 7, 'min_child_samples': 92, 'subsample': 0.9839576920274321, 'colsample_bytree': 0.9811120714902132, 'reg_alpha': 3.533446166926195, 'reg_lambda': 0.0007099905113302792}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:31,676] Trial 56 finished with value: 0.4239362730820842 and parameters: {'n_estimators': 620, 'learning_rate': 0.0068258259250471446, 'num_leaves': 40, 'max_depth': 5, 'min_child_samples': 88, 'subsample': 0.9228727135797915, 'colsample_bytree': 0.9208919471428823, 'reg_alpha': 0.04307028535077057, 'reg_lambda': 0.34767913553727386}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:36,562] Trial 57 finished with value: 0.42543857831370185 and parameters: {'n_estimators': 820, 'learning_rate': 0.0038544961255960707, 'num_leaves': 51, 'max_depth': 6, 'min_child_samples': 32, 'subsample': 0.948281531361699, 'colsample_bytree': 0.7776232486849004, 'reg_alpha': 0.007780373924537079, 'reg_lambda': 1.1485139766661288}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:39,684] Trial 58 finished with value: 0.42880772759702024 and parameters: {'n_estimators': 620, 'learning_rate': 0.010698439341113206, 'num_leaves': 31, 'max_depth': 11, 'min_child_samples': 68, 'subsample': 0.8008566722875669, 'colsample_bytree': 0.8911074916657485, 'reg_alpha': 0.5071968746632788, 'reg_lambda': 0.03138984322444853}. Best is trial 22 with value: 0.42161530388610347.
# [I 2024-11-30 07:58:42,414] Trial 59 finished with value: 0.42053634294956693 and parameters: {'n_estimators': 720, 'learning_rate': 0.0080471332618126, 'num_leaves': 40, 'max_depth': 6, 'min_child_samples': 62, 'subsample': 0.8462527946243993, 'colsample_bytree': 0.6561150463138162, 'reg_alpha': 0.12577846195573286, 'reg_lambda': 0.00016250067900248392}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:58:44,526] Trial 60 finished with value: 0.43048402589935675 and parameters: {'n_estimators': 720, 'learning_rate': 0.018979402482650683, 'num_leaves': 48, 'max_depth': 5, 'min_child_samples': 61, 'subsample': 0.8449522049921486, 'colsample_bytree': 0.646289780436039, 'reg_alpha': 0.1708620869943067, 'reg_lambda': 0.0001399369754108578}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:58:47,053] Trial 61 finished with value: 0.42361089340857677 and parameters: {'n_estimators': 720, 'learning_rate': 0.008043099132647514, 'num_leaves': 41, 'max_depth': 7, 'min_child_samples': 84, 'subsample': 0.7438711216352183, 'colsample_bytree': 0.6311266049767691, 'reg_alpha': 0.06549115078385773, 'reg_lambda': 1.1914138232946323e-05}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:58:49,636] Trial 62 finished with value: 0.4247827124742966 and parameters: {'n_estimators': 620, 'learning_rate': 0.004766896015216687, 'num_leaves': 35, 'max_depth': 6, 'min_child_samples': 65, 'subsample': 0.785440874737947, 'colsample_bytree': 0.5700040536213273, 'reg_alpha': 1.176990819016855, 'reg_lambda': 0.003637497809899709}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:58:51,489] Trial 63 finished with value: 0.42494126102669927 and parameters: {'n_estimators': 520, 'learning_rate': 0.006056515917504819, 'num_leaves': 39, 'max_depth': 5, 'min_child_samples': 79, 'subsample': 0.9643822765145944, 'colsample_bytree': 0.6732516634447743, 'reg_alpha': 0.009166013950528398, 'reg_lambda': 0.010791454385469714}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:58:54,661] Trial 64 finished with value: 0.4279058139369275 and parameters: {'n_estimators': 820, 'learning_rate': 0.016023806923702998, 'num_leaves': 46, 'max_depth': 6, 'min_child_samples': 51, 'subsample': 0.9865195833359451, 'colsample_bytree': 0.7382579553424273, 'reg_alpha': 9.528592480140535, 'reg_lambda': 0.0012846072320791854}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:58:57,319] Trial 65 finished with value: 0.42461635776701845 and parameters: {'n_estimators': 720, 'learning_rate': 0.008155175850742925, 'num_leaves': 34, 'max_depth': 7, 'min_child_samples': 72, 'subsample': 0.7208391295958994, 'colsample_bytree': 0.5875628536252803, 'reg_alpha': 0.023142874518892558, 'reg_lambda': 0.024732600927120048}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:58:59,392] Trial 66 finished with value: 0.42645060880091706 and parameters: {'n_estimators': 620, 'learning_rate': 0.0100510403646846, 'num_leaves': 31, 'max_depth': 14, 'min_child_samples': 100, 'subsample': 0.8987781404415617, 'colsample_bytree': 0.505972717979311, 'reg_alpha': 0.0025686028193037704, 'reg_lambda': 0.20349737934837828}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:00,694] Trial 67 finished with value: 0.4903593924778059 and parameters: {'n_estimators': 220, 'learning_rate': 0.0054516145899862435, 'num_leaves': 53, 'max_depth': 8, 'min_child_samples': 59, 'subsample': 0.9287226808596396, 'colsample_bytree': 0.9789357263793845, 'reg_alpha': 0.3884176431233742, 'reg_lambda': 0.00018892178838333977}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:06,032] Trial 68 finished with value: 0.4456138824855372 and parameters: {'n_estimators': 820, 'learning_rate': 0.012715871147746033, 'num_leaves': 38, 'max_depth': 12, 'min_child_samples': 41, 'subsample': 0.8580624187833371, 'colsample_bytree': 0.9387676895401572, 'reg_alpha': 0.12438514942190661, 'reg_lambda': 4.749098852438687e-05}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:08,225] Trial 69 finished with value: 0.4248831978853878 and parameters: {'n_estimators': 520, 'learning_rate': 0.006960052090774645, 'num_leaves': 74, 'max_depth': 9, 'min_child_samples': 81, 'subsample': 0.8185023943541752, 'colsample_bytree': 0.8385040125017839, 'reg_alpha': 1.616878268463683, 'reg_lambda': 0.002405200136239798}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:10,661] Trial 70 finished with value: 0.434067912204042 and parameters: {'n_estimators': 720, 'learning_rate': 0.02625591500915587, 'num_leaves': 66, 'max_depth': 6, 'min_child_samples': 92, 'subsample': 0.6374327227384289, 'colsample_bytree': 0.9158126958332478, 'reg_alpha': 5.093771940966511, 'reg_lambda': 4.967777224861654e-07}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:12,683] Trial 71 finished with value: 0.4230377546614978 and parameters: {'n_estimators': 620, 'learning_rate': 0.009338367450235717, 'num_leaves': 37, 'max_depth': 5, 'min_child_samples': 86, 'subsample': 0.9717660805102153, 'colsample_bytree': 0.9632253888592526, 'reg_alpha': 0.7824173774616145, 'reg_lambda': 0.07271977555771324}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:14,806] Trial 72 finished with value: 0.42380156568152927 and parameters: {'n_estimators': 620, 'learning_rate': 0.007844272369121143, 'num_leaves': 42, 'max_depth': 5, 'min_child_samples': 83, 'subsample': 0.9705344855816614, 'colsample_bytree': 0.9896193485203064, 'reg_alpha': 1.9631193341375566, 'reg_lambda': 0.01003883567901248}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:16,971] Trial 73 finished with value: 0.4248962230603638 and parameters: {'n_estimators': 620, 'learning_rate': 0.01043863349140651, 'num_leaves': 45, 'max_depth': 6, 'min_child_samples': 88, 'subsample': 0.9495263713008841, 'colsample_bytree': 0.9491436320545099, 'reg_alpha': 0.2972613958345598, 'reg_lambda': 0.045350729353441234}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:18,329] Trial 74 finished with value: 0.4238114777305292 and parameters: {'n_estimators': 420, 'learning_rate': 0.013347497443950689, 'num_leaves': 33, 'max_depth': 5, 'min_child_samples': 97, 'subsample': 0.9882703929338991, 'colsample_bytree': 0.9657394179697858, 'reg_alpha': 0.011681200014135047, 'reg_lambda': 0.02268354338645137}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:20,115] Trial 75 finished with value: 0.42956776753223913 and parameters: {'n_estimators': 520, 'learning_rate': 0.006380701696410321, 'num_leaves': 38, 'max_depth': 5, 'min_child_samples': 90, 'subsample': 0.9755315479445668, 'colsample_bytree': 0.9021618098902529, 'reg_alpha': 4.163851331815254, 'reg_lambda': 0.8190545567946046}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:23,639] Trial 76 finished with value: 0.4272174868684053 and parameters: {'n_estimators': 620, 'learning_rate': 0.009013031283619282, 'num_leaves': 50, 'max_depth': 6, 'min_child_samples': 21, 'subsample': 0.7645030178487412, 'colsample_bytree': 0.8584216333137709, 'reg_alpha': 0.04082080709608643, 'reg_lambda': 2.76307072711081}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:26,341] Trial 77 finished with value: 0.42685238796223784 and parameters: {'n_estimators': 720, 'learning_rate': 0.011270866651097224, 'num_leaves': 40, 'max_depth': 7, 'min_child_samples': 86, 'subsample': 0.9565171922688339, 'colsample_bytree': 0.9259325343200768, 'reg_alpha': 1.1249500945511854, 'reg_lambda': 0.12746002716619714}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:28,014] Trial 78 finished with value: 0.4251679187664597 and parameters: {'n_estimators': 520, 'learning_rate': 0.015122860962233716, 'num_leaves': 33, 'max_depth': 5, 'min_child_samples': 75, 'subsample': 0.9352853360352116, 'colsample_bytree': 0.8800586383028388, 'reg_alpha': 0.0013315858528693814, 'reg_lambda': 0.2628022315075874}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:30,343] Trial 79 finished with value: 0.43705112659049716 and parameters: {'n_estimators': 720, 'learning_rate': 0.021451861878797097, 'num_leaves': 43, 'max_depth': 6, 'min_child_samples': 78, 'subsample': 0.9124382975636833, 'colsample_bytree': 0.9393546984798695, 'reg_alpha': 0.0006730655420336001, 'reg_lambda': 0.005328939927022532}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:32,884] Trial 80 finished with value: 0.42298626382054455 and parameters: {'n_estimators': 720, 'learning_rate': 0.0082625496942357, 'num_leaves': 36, 'max_depth': 6, 'min_child_samples': 85, 'subsample': 0.9856973290553677, 'colsample_bytree': 0.9896247332190142, 'reg_alpha': 0.14353364031532, 'reg_lambda': 0.06273355939468331}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:35,400] Trial 81 finished with value: 0.4226488220496932 and parameters: {'n_estimators': 720, 'learning_rate': 0.00816428346776775, 'num_leaves': 37, 'max_depth': 6, 'min_child_samples': 93, 'subsample': 0.9999426651854574, 'colsample_bytree': 0.9712353362594265, 'reg_alpha': 0.5261248459973936, 'reg_lambda': 0.01700074501006917}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:37,610] Trial 82 finished with value: 0.4236094497856091 and parameters: {'n_estimators': 620, 'learning_rate': 0.007250201322079725, 'num_leaves': 31, 'max_depth': 6, 'min_child_samples': 93, 'subsample': 0.9979943974068421, 'colsample_bytree': 0.9748923484109816, 'reg_alpha': 0.06747784068117191, 'reg_lambda': 0.014921414664544637}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:40,095] Trial 83 finished with value: 0.4246437918402314 and parameters: {'n_estimators': 820, 'learning_rate': 0.010149724929411545, 'num_leaves': 38, 'max_depth': 5, 'min_child_samples': 90, 'subsample': 0.9656461027042605, 'colsample_bytree': 0.9533460909798663, 'reg_alpha': 0.5242862680531101, 'reg_lambda': 0.040917962238890514}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:42,703] Trial 84 finished with value: 0.4266485130447112 and parameters: {'n_estimators': 720, 'learning_rate': 0.005609304248920326, 'num_leaves': 45, 'max_depth': 7, 'min_child_samples': 98, 'subsample': 0.9809722231109287, 'colsample_bytree': 0.9629900165492287, 'reg_alpha': 2.520599885888953, 'reg_lambda': 0.08655779175713951}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:45,436] Trial 85 finished with value: 0.42880713993559894 and parameters: {'n_estimators': 620, 'learning_rate': 0.004351200541396114, 'num_leaves': 79, 'max_depth': 5, 'min_child_samples': 80, 'subsample': 0.9918698392199092, 'colsample_bytree': 0.9260810363419101, 'reg_alpha': 0.004068394575290694, 'reg_lambda': 0.008498832546410675}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:48,186] Trial 86 finished with value: 0.4268994061448674 and parameters: {'n_estimators': 720, 'learning_rate': 0.005177919427838919, 'num_leaves': 34, 'max_depth': 6, 'min_child_samples': 88, 'subsample': 0.9411038267760051, 'colsample_bytree': 0.9896074622931699, 'reg_alpha': 1.466121681514663, 'reg_lambda': 0.019928238158398167}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:50,614] Trial 87 finished with value: 0.4280678715920504 and parameters: {'n_estimators': 620, 'learning_rate': 0.012045348656867868, 'num_leaves': 41, 'max_depth': 7, 'min_child_samples': 83, 'subsample': 0.9589052776232845, 'colsample_bytree': 0.9138278178168725, 'reg_alpha': 0.623385806417718, 'reg_lambda': 0.0006068266765420534}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:52,913] Trial 88 finished with value: 0.42222785240492 and parameters: {'n_estimators': 620, 'learning_rate': 0.008502382343018674, 'num_leaves': 49, 'max_depth': 5, 'min_child_samples': 69, 'subsample': 0.9712637010214911, 'colsample_bytree': 0.9463786848042881, 'reg_alpha': 0.27403486858100506, 'reg_lambda': 0.0033112161292456303}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:56,034] Trial 89 finished with value: 0.42203151243544046 and parameters: {'n_estimators': 720, 'learning_rate': 0.006331974222493274, 'num_leaves': 56, 'max_depth': 6, 'min_child_samples': 64, 'subsample': 0.9995681883080143, 'colsample_bytree': 0.9434780065535938, 'reg_alpha': 0.026243440218236862, 'reg_lambda': 0.004226673166554754}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 07:59:59,073] Trial 90 finished with value: 0.4217995503919121 and parameters: {'n_estimators': 820, 'learning_rate': 0.006260999749509529, 'num_leaves': 55, 'max_depth': 5, 'min_child_samples': 56, 'subsample': 0.9998322536322573, 'colsample_bytree': 0.9474993147421835, 'reg_alpha': 0.027597873469268175, 'reg_lambda': 0.0018628421157603665}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 08:00:02,179] Trial 91 finished with value: 0.42150466917628115 and parameters: {'n_estimators': 820, 'learning_rate': 0.006163237760774791, 'num_leaves': 60, 'max_depth': 5, 'min_child_samples': 56, 'subsample': 0.9991820103443959, 'colsample_bytree': 0.9399724367017399, 'reg_alpha': 0.25269006560770163, 'reg_lambda': 0.001955266436769911}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 08:00:05,341] Trial 92 finished with value: 0.42165627157093394 and parameters: {'n_estimators': 920, 'learning_rate': 0.0066401653917336325, 'num_leaves': 56, 'max_depth': 5, 'min_child_samples': 63, 'subsample': 0.9750406202666837, 'colsample_bytree': 0.9467051598822549, 'reg_alpha': 0.02589388579269133, 'reg_lambda': 0.0016258509088621547}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 08:00:09,109] Trial 93 finished with value: 0.42176543218465234 and parameters: {'n_estimators': 920, 'learning_rate': 0.0038737189213595646, 'num_leaves': 59, 'max_depth': 5, 'min_child_samples': 56, 'subsample': 0.9822616271560063, 'colsample_bytree': 0.9399508372902083, 'reg_alpha': 0.02492123158094039, 'reg_lambda': 0.0016547877815169694}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 08:00:13,197] Trial 94 finished with value: 0.43791498364238113 and parameters: {'n_estimators': 920, 'learning_rate': 0.0021407996163948237, 'num_leaves': 59, 'max_depth': 5, 'min_child_samples': 57, 'subsample': 0.9894039305018973, 'colsample_bytree': 0.898387639917363, 'reg_alpha': 0.021903484501362726, 'reg_lambda': 0.0002791976672545697}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 08:00:17,037] Trial 95 finished with value: 0.4220985129973928 and parameters: {'n_estimators': 920, 'learning_rate': 0.003855863973392819, 'num_leaves': 65, 'max_depth': 5, 'min_child_samples': 54, 'subsample': 0.977980462244507, 'colsample_bytree': 0.9354987815046908, 'reg_alpha': 0.02907050591277253, 'reg_lambda': 0.0009289173360070317}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 08:00:21,014] Trial 96 finished with value: 0.42429239708535416 and parameters: {'n_estimators': 920, 'learning_rate': 0.0031006280253178488, 'num_leaves': 66, 'max_depth': 5, 'min_child_samples': 55, 'subsample': 0.9513096326210794, 'colsample_bytree': 0.9404137755668741, 'reg_alpha': 0.024469578384181966, 'reg_lambda': 8.151150213960836e-05}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 08:00:24,690] Trial 97 finished with value: 0.42311995689909027 and parameters: {'n_estimators': 920, 'learning_rate': 0.0034222440244539762, 'num_leaves': 60, 'max_depth': 5, 'min_child_samples': 63, 'subsample': 0.9929129659362526, 'colsample_bytree': 0.8831601549867667, 'reg_alpha': 0.033916483813083924, 'reg_lambda': 0.0009307555224519796}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 08:00:28,621] Trial 98 finished with value: 0.4230251624356889 and parameters: {'n_estimators': 920, 'learning_rate': 0.00377871552592527, 'num_leaves': 56, 'max_depth': 5, 'min_child_samples': 49, 'subsample': 0.9759739140338956, 'colsample_bytree': 0.9303891636534417, 'reg_alpha': 0.006405157795734318, 'reg_lambda': 0.0016745318665011767}. Best is trial 59 with value: 0.42053634294956693.
# [I 2024-11-30 08:00:31,908] Trial 99 finished with value: 0.4215324270003474 and parameters: {'n_estimators': 820, 'learning_rate': 0.004287587855359731, 'num_leaves': 68, 'max_depth': 5, 'min_child_samples': 60, 'subsample': 0.9836364506301686, 'colsample_bytree': 0.9121534857114123, 'reg_alpha': 0.0656782519939705, 'reg_lambda': 0.0019863920852476527}. Best is trial 59 with value: 0.42053634294956693.
# Best trial:
#   Value: 0.42053634294956693
#   Params: {'n_estimators': 720, 'learning_rate': 0.0080471332618126, 'num_leaves': 40, 'max_depth': 6, 'min_child_samples': 62, 'subsample': 0.8462527946243993, 'colsample_bytree': 0.6561150463138162, 'reg_alpha': 0.12577846195573286, 'reg_lambda': 0.00016250067900248392}

# %%
best_params = {'n_estimators': 720, 'learning_rate': 0.0080471332618126, 'num_leaves': 40, 'max_depth': 6, 'min_child_samples': 62, 'subsample': 0.8462527946243993, 'colsample_bytree': 0.6561150463138162, 'reg_alpha': 0.12577846195573286, 'reg_lambda': 0.00016250067900248392}

# %%
cross_validator = KFold(n_splits = 5, shuffle=True, random_state = 1000)
model = lgbm.LGBMRegressor(**best_params)
print(cross_validate(model, ft_df, cross_validator))
lgbm.plot_importance(model, importance_type="gain", figsize=(10, 8))
# Out:
# {0: 0.36973535701760263, 1: 0.43477893012742946, 2: 0.38032676293126977, 3: 0.40892160440009695, 4: 0.4000859552510211}
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# ## PyTorch Feed Forward Neural Network

# %%
import torch
from torch import nn
import torch.optim.lr_scheduler as sched

# %%
def learn_pt(X_train, X_valid, y_train, y_valid, params):
    # hyperparams
    batch_size = params["bs"]
    learning_rate = params["lr"]
    n_epochs = params["n_epochs"]
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    X_train = torch.tensor(X_train.values, dtype=torch.float32).to(device)
    y_train = torch.tensor(y_train.values, dtype=torch.float32).reshape(-1, 1).to(device)
    X_valid = torch.tensor(X_valid.values, dtype=torch.float32).to(device)
    y_valid = torch.tensor(y_valid.values, dtype=torch.float32).reshape(-1, 1).to(device)

    model = nn.Sequential(nn.Linear(30, 32), nn.LayerNorm(32), nn.ReLU(),
                     nn.Linear(32, 64), nn.LayerNorm(64), nn.ReLU(),
                     nn.Linear(64, 32), nn.LayerNorm(32), nn.ReLU(),
                     nn.Linear(32, 1),).to(device)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = sched.ReduceLROnPlateau(optimizer, factor=params["factor"], patience=params["patience"])

    train_loss_history=[]
    val_loss_history=[]
    loss_fn = nn.MSELoss()
    batch_start = torch.arange(0, len(X_train), batch_size)

    count=0
    for epoch in range(n_epochs):
        print("EPOCH ", epoch+1)
        
        ## TRAIN PHASE :
        model.train()
        losses = []
        for features, labels in zip(X_train, y_train):
            features, labels = features.to(device), labels.to(device)
            optimizer.zero_grad()
            preds = model(features)
            loss = loss_fn(preds, labels)
            losses.append(float(loss)) 
            loss.backward()
            optimizer.step()
        with tqdm(batch_start, unit="batch", mininterval=0, disable=True) as bar:
            bar.set_description(f"Epoch {epoch}")
            for start in bar:
                X_batch = X_train[start:start+batch_size]
                y_batch = y_train[start:start+batch_size]
                optimizer.zero_grad()
                y_pred = model(X_batch)
                loss = loss_fn(y_pred, y_batch)
                losses.append(float(loss))
                loss.backward()
                optimizer.step()
                bar.set_postfix(mse=float(loss))

        avg_loss = np.mean(losses)
        train_loss_history.append(avg_loss)

        print(f"Train Loss : {avg_loss}")
        
        ## VALIDATION PHASE : 
        model.eval()
        losses = []
        for features, labels in zip(X_valid, y_valid):
            features, labels = features.to(device), labels.to(device)
            preds = model(features)
            loss  = loss_fn(preds, labels)
            losses.append(float(loss))

        avg_loss = np.mean(losses)
        val_loss_history.append(avg_loss)

        print(f"Valid Loss : {avg_loss}")
        
        scheduler.step(avg_loss)
        count+=1
    losses_history = {"train" : train_loss_history, "valid" : val_loss_history}
    
    return model, losses_history

# %%
split_idx = int(0.8*len(ft_df))
end_idx = len(ft_df)

shuffled_df = ft_df.sample(frac=1, random_state = 404)

X_train = shuffled_df.iloc[0:split_idx].drop('score', axis=1)
X_valid = shuffled_df.iloc[split_idx:end_idx].drop('score', axis=1)
y_train = shuffled_df.iloc[0:split_idx]['score']
y_valid = shuffled_df.iloc[split_idx:end_idx]['score']

params = {"bs": 5,"lr": 0.001, "n_epochs":20, "factor": 0.5, "patience": 2}

mod, losses = learn_pt(X_train, X_valid, y_train, y_valid, params)
# Out:
# EPOCH  1
# Train Loss : 0.7548350361235036
# Valid Loss : 0.49323222214269286
# EPOCH  2
# Train Loss : 0.4884924839894827
# Valid Loss : 0.4507261146951424
# EPOCH  3
# Train Loss : 0.46787280765643086
# Valid Loss : 0.4466530130695354
# EPOCH  4
# Train Loss : 0.45647816981140765
# Valid Loss : 0.44254176083153185
# EPOCH  5
# Train Loss : 0.4506911942789652
# Valid Loss : 0.44261201938228856
# EPOCH  6
# Train Loss : 0.4460037657308083
# Valid Loss : 0.44353538388080643
# EPOCH  7
# Train Loss : 0.4414100900907905
# Valid Loss : 0.44357325409967374
# EPOCH  8
# Train Loss : 0.41849228344852335
# Valid Loss : 0.44301890437428815
# EPOCH  9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[178], line 13
#       9 y_valid = shuffled_df.iloc[split_idx:end_idx]['score']
#      11 params = {"bs": 5,"lr": 0.001, "n_epochs":20, "factor": 0.5, "patience": 2}
# ---> 13 mod, losses = learn_pt(X_train, X_valid, y_train, y_valid, params)
#
# Cell In[176], line 39, in learn_pt(X_train, X_valid, y_train, y_valid, params)
#      37     loss = loss_fn(preds, labels)
#      38     losses.append(float(loss))
# ---> 39     loss.backward()
#      40     optimizer.step()
#      41 with tqdm(batch_start, unit="batch", mininterval=0, disable=True) as bar:
#
# File /opt/conda/lib/python3.11/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File /opt/conda/lib/python3.11/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %% [markdown]
# # Since I'm doing NN, might as well do tensorflow too

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, LayerNormalization, ReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
def learn_tf(X_train, X_valid, y_train, y_valid, params):
    learning_rate = params['lr']
    batch_size = params['bs']
    n_epochs = params['n_epochs']
    
    model = keras.Sequential([
        Dense(32, input_dim=30), LayerNormalization(), ReLU(),
        Dense(64), LayerNormalization(), ReLU(),
        Dense(128), LayerNormalization(), ReLU(),
        Dense(64), LayerNormalization(), ReLU(),
        Dense(32), LayerNormalization(), ReLU(),
        Dense(1)])

    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=params['factor'], patience=params['patience'], verbose=1)
    
    history = model.fit(
        X_train, y_train,
        validation_data=(X_valid, y_valid),
        batch_size=batch_size,
        epochs=n_epochs,
        callbacks=[reduce_lr]
    )
    
    
    loss= model.evaluate(X_valid, y_valid)
    print(f"Validation Loss: {loss}")

    return model, history

# %%
shuffled_df = ft_df.sample(frac=1, random_state = 404)
X_train = shuffled_df.iloc[0:split_idx].drop('score', axis=1)
X_valid = shuffled_df.iloc[split_idx:end_idx].drop('score', axis=1)
y_train = shuffled_df.iloc[0:split_idx]['score']
y_valid = shuffled_df.iloc[split_idx:end_idx]['score']

params = {"bs": 10,"lr": 0.001, "n_epochs":20, "factor": 0.5, "patience": 2}

learn_tf(X_train, X_valid, y_train, y_valid, params)
# Out:
# Epoch 1/20
# 198/198 [==============================] - 6s 9ms/step - loss: 0.7483 - val_loss: 0.7009 - lr: 0.0010
# Epoch 2/20
# 198/198 [==============================] - 1s 7ms/step - loss: 0.5440 - val_loss: 0.5794 - lr: 0.0010
# Epoch 3/20
# 198/198 [==============================] - 1s 7ms/step - loss: 0.5076 - val_loss: 0.6231 - lr: 0.0010
# Epoch 4/20
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4937 - val_loss: 0.5006 - lr: 0.0010
# Epoch 5/20
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4751 - val_loss: 0.6337 - lr: 0.0010
# Epoch 6/20
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4725 - val_loss: 0.4810 - lr: 0.0010
# Epoch 7/20
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4492 - val_loss: 0.4665 - lr: 0.0010
# Epoch 8/20
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4671 - val_loss: 0.4581 - lr: 0.0010
# Epoch 9/20
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4483 - val_loss: 0.4803 - lr: 0.0010
# Epoch 10/20
# 198/198 [==============================] - ETA: 0s - loss: 0.4399
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4399 - val_loss: 0.4605 - lr: 0.0010
# Epoch 11/20
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4260 - val_loss: 0.4608 - lr: 5.0000e-04
# Epoch 12/20
# 194/198 [============================>.] - ETA: 0s - loss: 0.4228
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4231 - val_loss: 0.4682 - lr: 5.0000e-04
# Epoch 13/20
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4087 - val_loss: 0.4449 - lr: 2.5000e-04
# Epoch 14/20
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4113 - val_loss: 0.4418 - lr: 2.5000e-04
# Epoch 15/20
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4115 - val_loss: 0.4511 - lr: 2.5000e-04
# Epoch 16/20
# 195/198 [============================>.] - ETA: 0s - loss: 0.4094
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4075 - val_loss: 0.4528 - lr: 2.5000e-04
# Epoch 17/20
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4049 - val_loss: 0.4487 - lr: 1.2500e-04
# Epoch 18/20
# 197/198 [============================>.] - ETA: 0s - loss: 0.4051
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 198/198 [==============================] - 1s 7ms/step - loss: 0.4046 - val_loss: 0.4449 - lr: 1.2500e-04
# Epoch 19/20
# 198/198 [==============================] - 1s 7ms/step - loss: 0.3989 - val_loss: 0.4440 - lr: 6.2500e-05
# Epoch 20/20
# 193/198 [============================>.] - ETA: 0s - loss: 0.4030
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 198/198 [==============================] - 1s 7ms/step - loss: 0.3998 - val_loss: 0.4433 - lr: 6.2500e-05
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4433
# Validation Loss: 0.44334477186203003
# (<keras.src.engine.sequential.Sequential at 0x7f0770f2d610>,
#  <keras.src.callbacks.History at 0x7f07709e0050>)
